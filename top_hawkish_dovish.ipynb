# %% [markdown]
# <a href="https://colab.research.google.com/github/sunnyna/TIL/blob/master/top_hawkish_dovish.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/drive/My Drive/BOK_project/new_dic4_all_merged.csv')

df
# Out:
#                               ngrams  cnt_up  ...  polarity score  label
# 0                      수익/NNG;약화/NNG       5  ...        4.056017      1
# 1                      수익/NNG;향상/NNG      15  ...        3.810198      1
# 2                             징수/NNG     224  ...        1.324474      1
# 3                           영업시간/NNG      99  ...        1.655121      1
# 4                             타행/NNG     134  ...        1.310855      1
# ...                              ...     ...  ...             ...    ...
# 143660                 성장/NNG;성공/NNG       1  ...        3.318559      1
# 143661                       톤세제/NNG       2  ...        5.530932      1
# 143662          불안/NNG;환율/NNG;하락/NNG       1  ...        3.318559      1
# 143663          공급/NNG;강도/NNG;약화/NNG       1  ...        3.318559      1
# 143664   인상/NNG;부담/NNG;금리/NNG;인상/NNG       1  ...        3.318559      1
#
# [143665 rows x 7 columns]

# %%
df_neg = df.drop(df[df.label == 1].index)

df_neg
# Out:
#                           ngrams  cnt_up  ...  polarity score  label
# 6                       자구계획/NNG     122  ...        0.746600     -1
# 18                      부채한도/NNG     298  ...        0.437057     -1
# 20                       재수주/NNG     142  ...        0.566002     -1
# 21         거시/NNG;건전성/NNG;강화/NNG       4  ...        0.321151     -1
# 28                         살린/VV      38  ...        0.753773     -1
# ...                          ...     ...  ...             ...    ...
# 143644      둔화/NNG;물가/NNG;압력/NNG       0  ...        0.368729     -1
# 143645                    찬도/NNG       0  ...        0.368729     -1
# 143646      소비/NNG;소폭/MAG;증가/NNG       0  ...        0.368729     -1
# 143647              인하/NNG;못하/VX       0  ...        0.368729     -1
# 143648   fed/NNG;불확실성/NNG;경계/NNG       0  ...        0.368729     -1
#
# [72290 rows x 7 columns]

# %%
df_pos = df.drop(df[df.label == -1].index)
df_pos.reset_index(drop=True, inplace=True)

# %%
df_pos
# Out:
#                              ngrams  cnt_up  ...  polarity score  label
# 0                     수익/NNG;약화/NNG       5  ...        4.056017      1
# 1                     수익/NNG;향상/NNG      15  ...        3.810198      1
# 2                            징수/NNG     224  ...        1.324474      1
# 3                          영업시간/NNG      99  ...        1.655121      1
# 4                            타행/NNG     134  ...        1.310855      1
# ...                             ...     ...  ...             ...    ...
# 71370                 성장/NNG;성공/NNG       1  ...        3.318559      1
# 71371                       톤세제/NNG       2  ...        5.530932      1
# 71372          불안/NNG;환율/NNG;하락/NNG       1  ...        3.318559      1
# 71373          공급/NNG;강도/NNG;약화/NNG       1  ...        3.318559      1
# 71374   인상/NNG;부담/NNG;금리/NNG;인상/NNG       1  ...        3.318559      1
#
# [71375 rows x 7 columns]

# %%
df_neg.sort_values(by=['polarity score'], axis=0, ascending=True).head(60)
# Out:
#                          ngrams  cnt_up  ...  polarity score  label
# 73252                   수쿠크/NNG       0  ...        0.003170     -1
# 128629               구제금융법안/NNG       1  ...        0.004902     -1
# 96738                  초과이익/NNG       0  ...        0.006545     -1
# 96719               모델포트폴리오/NNG       0  ...        0.006624     -1
# 73253                 이슬람금융/NNG       0  ...        0.007137     -1
# 15184                    왕좌/NNG       0  ...        0.007326     -1
# 73259                   샤리아/NNG       0  ...        0.008317     -1
# 14997                    입량/NNG       0  ...        0.013014     -1
# 68198                   간통죄/NNG       0  ...        0.015153     -1
# 27815                    국신/NNG       0  ...        0.016032     -1
# 15123                    표주/NNG       0  ...        0.016032     -1
# 120663                금융규제안/NNG       0  ...        0.017018     -1
# 87476                   종목군/NNG       0  ...        0.018134     -1
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.rcParams['font.family'] = 'NanumGothic'
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
import matplotlib.font_manager as fm

# 설치된 폰트 출력
font_list = [font.name for font in fm.fontManager.ttflist]
font_list
# Out:
# ['STIXSizeFourSym',
#  'DejaVu Serif',
#  'STIXSizeFourSym',
#  'STIXNonUnicode',
#  'DejaVu Sans',
#  'cmmi10',
#  'cmtt10',
#  'cmsy10',
#  'STIXNonUnicode',
#  'DejaVu Sans',
#  'STIXGeneral',
#  'DejaVu Sans Mono',
#  'STIXSizeOneSym',
#  'cmex10',
#  'DejaVu Sans Mono',
#  'STIXSizeFiveSym',
#  'STIXSizeThreeSym',
#  'cmb10',
#  'DejaVu Serif',
#  'DejaVu Sans Display',
#  'DejaVu Sans',
#  'STIXGeneral',
#  'DejaVu Sans Mono',
#  'DejaVu Sans',
#  'STIXSizeOneSym',
#  'STIXNonUnicode',
#  'DejaVu Serif Display',
#  'STIXNonUnicode',
#  'cmss10',
#  'cmr10',
#  'STIXGeneral',
#  'STIXSizeThreeSym',
#  'STIXSizeTwoSym',
#  'STIXGeneral',
#  'DejaVu Serif',
#  'DejaVu Sans Mono',
#  'DejaVu Serif',
#  'STIXSizeTwoSym',
#  'Liberation Sans Narrow',
#  'Liberation Serif',
#  'Liberation Sans Narrow',
#  'Liberation Mono',
#  'Liberation Sans',
#  'Liberation Sans',
#  'NanumSquare',
#  'Liberation Mono',
#  'NanumSquareRound',
#  'Liberation Sans Narrow',
#  'NanumGothic',
# ...

# %%
import re

A = re.findall('[가-힣]+/+NNG' , '통화정책/NNG;경제/NNG;견조/NNG;성장/NNG	')
B = re.findall('[가-힣]+/+VV' , '통화정책/NNG;경제/NNG;견조/NNG;성장/NNG	')

# %%
A, B
# Out:
# (['통화정책/NNG', '경제/NNG', '견조/NNG', '성장/NNG'], [])

# %%
df_pos.sort_values(by=['polarity score'], axis=0, ascending=False).head(60)
# Out:
#                                ngrams  cnt_up  ...  polarity score  label
# 13408                          별주/NNG      96  ...      213.493978      1
# 7088                         예정이율/NNG      91  ...      202.432114      1
# 36270                          짊어지/VV      54  ...      120.574319      1
# 7149                         공시이율/NNG      41  ...       91.813472      1
# 981                          암호화폐/NNG      39  ...       87.388727      1
# 12108                          바뀐다/VV      39  ...       87.388727      1
# 16433                          배년/NNG      36  ...       80.751608      1
# 65911                          비엘/NNG      32  ...       71.902117      1
# 7189                           중좌/NNG      32  ...       71.902117      1
# 13409                          달달/MAG      32  ...       71.902117      1
# 7075                         개인연금/NNG      30  ...       67.477371      1
# 470                           수소탄/NNG      89  ...       66.002456      1
# ...

# %%
nng = []
vv = []
import re
from tqdm import tqdm
for i in tqdm(range(len(df_pos['ngrams']))):
  nng.append(re.findall('[가-힣]+/+NNG',df_pos['ngrams'][i]))
  vv.append(re.findall('[가-힣]+/+VV', df_pos['ngrams'][i]))
# Out:
# 100%|██████████| 71375/71375 [00:02<00:00, 26056.45it/s]

# %%
nng
# Out:
# [['수익/NNG', '약화/NNG'],
#  ['수익/NNG', '향상/NNG'],
#  ['징수/NNG'],
#  ['영업시간/NNG'],
#  ['타행/NNG'],
#  ['계좌유지수수료/NNG'],
#  [],
#  [],
#  [],
#  ['기사/NNG'],
#  ['제보/NNG'],
#  ['문의/NNG'],
#  ['채팅/NNG'],
#  ['최신/NNG'],
#  ['지수/NNG', '상승/NNG'],
#  ['새해/NNG'],
#  ['세제개편안/NNG'],
#  ['챌린저/NNG'],
#  ['환경/NNG', '불확실성/NNG'],
#  ['성장/NNG'],
#  ['금융인/NNG'],
#  ['블록체인/NNG'],
#  ['내실/NNG'],
#  ['국제경쟁력/NNG'],
#  ['혈맥/NNG'],
#  ['모험자본/NNG'],
#  ['혁신기업/NNG'],
#  ['태산/NNG'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['금리/NNG', '금리/NNG'],
#  ['금융채/NNG', '금리/NNG'],
#  ['인플레이션/NNG', '물가/NNG', '상승/NNG'],
#  ['총선/NNG', '정치/NNG', '불확실성/NNG'],
#  ['경제/NNG', '예상/NNG', '견조/NNG'],
#  ['예상/NNG', '견조/NNG', '성장/NNG'],
#  ['경제/NNG', '내외/NNG', '성장/NNG'],
#  ['회복/NNG', '경기/NNG', '회복/NNG'],
#  ['수출/NNG', '호조/NNG'],
#  ['권태/NNG'],
#  ['확장국면/NNG'],
#  ['박병/NNG'],
#  ['건전성/NNG', '규제/NNG', '강화/NNG'],
#  ['소비자/NNG', '신뢰/NNG', '회복/NNG'],
#  ['실업률/NNG', '경기/NNG', '회복/NNG'],
#  ['신년사/NNG'],
#  ['융합/NNG'],
#  ['사신/NNG'],
# ...

# %%
vv
# Out:
# [[],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['거스를/VV'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['옮길/VV'],
#  [],
#  [],
#  [],
#  [],
#  ['오르/VV', '오르/VV'],
#  ['오르/VV'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['맺/VV'],
#  ['오르/VV'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['오르/VV'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['밀어붙여/VV'],
#  [],
#  [],
# ...

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# fonts-nanum is already the newest version (20170925-1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-440
# Use 'sudo apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 35 not upgraded.
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 10 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /var/cache/fontconfig: cleaning cache directory
# ...

# %%
import matplotlib.pyplot as plt

plt.rc('font', family='NanumBarunGothic')

# %%
df_d = pd.DataFrame({
       'ngrams': ['추경/NNG;불확실성/NNG','공장/NNG;재수주/NNG;증가/NNG','은행/NNG;영업/NNG;중단/NNG	','부채한도/NNG;증액/NNG;실패/NNG' ,'탈퇴/NNG;우려/NNG;완화/NNG	']	,
       'score': [0.020871,0.028364,0.031605,0.031605,0.033521],
})

df_h = pd.DataFrame({
   'ngrams': ['물가/NNG;부진/NNG;일시적/VAX','통화정책/NNG;경제/NNG;견조/NNG;성장/NNG','신용경색/NNG;공포/NNG','가격/NNG;부담/NNG;인식/NNG;높/VA	','고용/NNG;지표/NNG;임금/NNG;상승/NNG']
    'score' :[40.928897,38.716525,38.716525,36.504152,32.079406	] 
    
})

# %%
df_d = pd.DataFrame({
       'ngrams': ['추경;불확실성','공장;재수주;증가','은행;영업;중단','부채한도;증액;실패' ,'탈퇴;우려;완화']	,
       'score': [0.020871,0.028364,0.031605,0.031605,0.033521],
})

df_h = pd.DataFrame({
   'ngrams': ['물가;부진;일시적','통화정책;경제;견조;성장','신용경색;공포','가격;부담;인식;높	','고용;지표;임금;상승'],
    'score' :[40.928897,38.716525,38.716525,36.504152,32.079406	] 
    
})

# %%
plt.figure(figsize=(12, 5))
sns.set_palette("pastel")
ax = sns.barplot(x=df_d.score, y=df_d.index, orient='h')
# sns.set_context(context=None, font_scale =30, rc=None)
plt.rcParams.update({'font.size': 20})

ax.set_yticklabels(df_d.ngrams)

plt.title("The Most Dovishest Ngrams",fontsize=30)
plt.ylabel('Ngrams',fontsize=15)
plt.xlabel('Polarity Score',fontsize=15)
plt.savefig('Dovishest Ngrams.png')
plt.show();

# %%
plt.figure(figsize=(12, 5))
sns.set_palette("pastel")
ax = sns.barplot(x=df_h.score, y=df_h.index, orient='h')
# sns.set_context(context=None, font_scale =30, rc=None)
plt.rcParams.update({'font.size': 20})

ax.set_yticklabels(df_h.ngrams)

plt.title("The Most Hawkishest Ngrams",fontsize=30)
plt.ylabel('Ngrams',fontsize=15)
plt.xlabel('Polarity Score',fontsize=15)
plt.savefig('Hawkishest Ngrams.png')
plt.show();
