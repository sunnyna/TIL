# %% [markdown]
# <a href="https://colab.research.google.com/github/sunnyna/TIL/blob/master/seq2seq_mecab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %tensorflow_version 2.x
import tensorflow as tf
print("Tensorflow version " + tf.__version__)

try:
  tpu = tf.distribute.cluster_resolver.TPUClusterResolver()  # TPU detection
  print('Running on TPU ', tpu.cluster_spec().as_dict()['worker'])
except ValueError:
  raise BaseException('ERROR: Not connected to a TPU runtime; please see the previous cell in this notebook for instructions!')

tf.config.experimental_connect_to_cluster(tpu)
tf.tpu.experimental.initialize_tpu_system(tpu)
tpu_strategy = tf.distribute.experimental.TPUStrategy(tpu)
# Out:
# Tensorflow version 2.3.0
# Running on TPU  ['10.26.35.194:8470']
# INFO:tensorflow:Initializing the TPU system: grpc://10.26.35.194:8470
# INFO:tensorflow:Initializing the TPU system: grpc://10.26.35.194:8470
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Finished initializing TPU system.
# INFO:tensorflow:Finished initializing TPU system.
# WARNING:absl:`tf.distribute.experimental.TPUStrategy` is deprecated, please use  the non experimental symbol `tf.distribute.TPUStrategy` instead.
# INFO:tensorflow:Found TPU system:
# INFO:tensorflow:Found TPU system:
# INFO:tensorflow:*** Num TPU Cores: 8
# INFO:tensorflow:*** Num TPU Cores: 8
# INFO:tensorflow:*** Num TPU Workers: 1
# INFO:tensorflow:*** Num TPU Workers: 1
# INFO:tensorflow:*** Num TPU Cores Per Worker: 8
# INFO:tensorflow:*** Num TPU Cores Per Worker: 8
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:0, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:0, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:1, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:1, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:2, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:2, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:3, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:3, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:4, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:4, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:5, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:5, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:6, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:6, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:7, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:7, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 0, 0)

# %%
# Colab에 Mecab 설치
# !git clone https://github.com/SOMJANG/Mecab-ko-for-Google-Colab.git
# %cd Mecab-ko-for-Google-Colab
# !bash install_mecab-ko_on_colab190912.sh

# %%
from torchtext import data # torchtext.data 임포트
from konlpy.tag import Mecab

# %%
import pandas as pd
import urllib3
import zipfile
import shutil
import os
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical

# %%
df = pd.read_excel('/content/drive/My Drive/seq2seq project/kor.xlsx',
                    sheet_name='Sheet1')
# df = pd.read_excel('/content/drive/My Drive/seq2seq project/news.xlsx',
#                     )

# %%
df.sample(10)

# %%
df.drop(['mid_sid'], axis='columns', inplace=True)

# %%
df.sample(10)

# %%
import tensorflow as tf

import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from sklearn.model_selection import train_test_split

import unicodedata
import re
import numpy as np
import os
import io
import time

# %%
mecab = Mecab()

def preprocessing_src():
  src_vocab=[]
  for line in df.en: # source data 전처리
    temp_x = []
    temp_x = mecab.morphs(line)
    temp_x.insert(0, '<start>')
    temp_x.append('<end>')
    src_vocab.append(temp_x)
  return src_vocab

def preprocessing_tar():
  tar_vocab=[]
  for line in df.ko: # target data 전처리
    temp_x = []
    temp_x = mecab.morphs(line)
    temp_x.insert(0, '<start>')
    temp_x.append('<end>')
    tar_vocab.append(temp_x)
  return tar_vocab

src_vocab, tar_vocab
# Out:
# ([['<start>',
#    'I',
#    'go',
#    'to',
#    'the',
#    'attic',
#    'every',
#    'evening',
#    'to',
#    'meet',
#    'Bat',
#    '.',
#    '<end>'],
#   ['<start>',
#    'Sir',
#    ',',
#    'I',
#    'don',
#    "'",
#    't',
#    'understand',
#    'this',
#    'sentence',
#    'here',
#    '.',
#    '<end>'],
#   ['<start>',
#    'Time',
#    'flies',
#    'when',
#    'you',
#    'start',
#    'using',
#    'the',
#    'computer',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    "'",
#    'm',
#    'going',
#    'back',
#    'to',
#    'Korea',
#    'today',
#    'at',
#    'midnight',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'go',
#    'to',
#    'bathroom',
#    'as',
#    'soon',
#    'as',
#    'I',
#    'wake',
#    'up',
#    '.',
#    '<end>'],
#   ['<start>',
#    'If',
#    'I',
#    'fall',
#    'asleep',
#    'I',
#    'might',
#    'not',
#    'get',
#    'up',
#    'so',
#    'I',
#    'will',
#    'go',
#    'right',
#    'now',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'go',
#    'to',
#    'dormitory',
#    'as',
#    'soon',
#    'as',
#    'I',
#    'finished',
#    'class',
#    '.',
#    '<end>'],
#   ['<start>',
#    'Korean',
#    'men',
#    'have',
#    'to',
#    'obligatorily',
#    'join',
#    'the',
#    'army',
#    'in',
#    'twenty',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    "'",
#    'm',
#    'going',
#    'to',
#    'Korea',
#    'for',
#    'Visa',
#    'tonight',
#    '.',
#    '<end>'],
#   ['<start>',
#    'Today',
#    ',',
#    'I',
#    'am',
#    'going',
#    'to',
#    'pick',
#    'up',
#    'the',
#    'new',
#    'car',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    "'",
#    'm',
#    'meeting',
#    'a',
#    'guest',
#    'for',
#    'urgent',
#    'matters',
#    '.',
#    '<end>'],
#   ['<start>',
#    'He',
#    'leaves',
#    'for',
#    'Suwon',
#    'in',
#    'a',
#    'few',
#    'minutes',
#    '.',
#    '<end>'],
#   ['<start>',
#    'It',
#    'has',
#    'an',
#    'animal',
#    'hospital',
#    ',',
#    'so',
#    'I',
#    'took',
#    'puppies',
#    'there',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'take',
#    'a',
#    'shower',
#    ',',
#    'wear',
#    'a',
#    'school',
#    'uniform',
#    ',',
#    'and',
#    'go',
#    'to',
#    'school',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'will',
#    'go',
#    'ice',
#    'fishing',
#    'early',
#    'in',
#    'the',
#    'morning',
#    'tomorrow',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    "'",
#    'm',
#    'going',
#    'to',
#    'Seoul',
#    'to',
#    'do',
#    'another',
#    'job',
#    '.',
#    '<end>'],
#   ['<start>',
#    'Things',
#    'that',
#    'would',
#    'happen',
#    'in',
#    'a',
#    'movie',
#    'is',
#    'becoming',
#    'real',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'always',
#    'get',
#    'up',
#    'early',
#    'and',
#    'go',
#    'to',
#    'school',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'am',
#    'going',
#    'back',
#    'to',
#    'home',
#    'after',
#    'work',
#    '.',
#    '<end>'],
#   ['<start>',
#    'She',
#    'goes',
#    'to',
#    'piano',
#    'academy',
#    'every',
#    'Thursday',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'always',
#    'go',
#    'to',
#    'my',
#    'grandfather',
#    "'",
#    's',
#    'house',
#    'on',
#    'Tuesdays',
#    '.',
#    '<end>'],
#   ['<start>',
#    'We',
#    'go',
#    'to',
#    'music',
#    'academy',
#    'every',
#    'Friday',
#    '.',
#    '<end>'],
#   ['<start>',
#    'We',
#    'go',
#    'to',
#    'school',
#    'five',
#    'times',
#    'a',
#    'week',
#    '.',
#    '<end>'],
#   ['<start>',
#    'We',
#    'are',
#    'going',
#    'on',
#    'an',
#    'excursion',
#    'to',
#    'Buyeo',
#    'on',
#    'Saturday',
#    '.',
#    '<end>'],
#   ['<start>',
#    'We',
#    'came',
#    'on',
#    'Saturday',
#    ',',
#    'and',
#    'we',
#    'are',
#    'going',
#    'to',
#    'go',
#    'back',
#    'on',
#    'Friday',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'go',
#    'to',
#    'the',
#    'supermarket',
#    'once',
#    'a',
#    'week',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'did',
#    'my',
#    'business',
#    'at',
#    'a',
#    'bank',
#    ',',
#    'and',
#    'I',
#    'am',
#    'going',
#    'to',
#    'meet',
#    'my',
#    'friend',
#    '.',
#    '<end>'],
#   ['<start>',
#    'Time',
#    'on',
#    'Monday',
#    'flies',
#    'like',
#    'an',
#    'arrow',
#    '.',
#    '<end>'],
#   ['<start>',
#    'Today',
#    "'",
#    's',
#    'Friday',
#    'and',
#    'Chuseok',
#    "'",
#    's',
#    'almost',
#    'over',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'will',
#    'go',
#    'to',
#    'the',
#    'office',
#    'next',
#    'Monday',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'will',
#    'be',
#    'going',
#    'back',
#    'to',
#    'Korea',
#    'next',
#    'Thursday',
#    '.',
#    '<end>'],
#   ['<start>',
#    'Let',
#    "'",
#    's',
#    'go',
#    'watch',
#    'a',
#    'movie',
#    'together',
#    'this',
#    'Saturday',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'will',
#    'go',
#    'to',
#    'Lotte',
#    'world',
#    'with',
#    'my',
#    'students',
#    'this',
#    'Saturday',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'am',
#    'going',
#    'to',
#    'Korea',
#    'this',
#    'Saturday',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'am',
#    'going',
#    'to',
#    'Legoland',
#    'this',
#    'Friday',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'am',
#    'going',
#    'to',
#    'the',
#    'English',
#    'village',
#    'with',
#    'my',
#    'friend',
#    'next',
#    'Monday',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'am',
#    'going',
#    'to',
#    'Vietnam',
#    'this',
#    'Sunday',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'am',
#    'going',
#    'school',
#    'until',
#    'next',
#    'Monday',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'am',
#    'going',
#    'to',
#    'my',
#    'grandma',
#    "'",
#    's',
#    'place',
#    'this',
#    'Thursday',
#    '.',
#    '<end>'],
#   ['<start>',
#    'We',
#    'are',
#    'going',
#    'on',
#    'a',
#    'family',
#    'trip',
#    'to',
#    'Italy',
#    'this',
#    'Friday',
#    '.',
#    '<end>'],
#   ['<start>',
#    'My',
#    'sister',
#    'is',
#    'going',
#    'on',
#    'study',
#    'abroad',
#    'this',
#    'Friday',
#    '.',
#    '<end>'],
#   ['<start>',
#    'Thus',
#    ',',
#    'I',
#    'have',
#    'great',
#    'interested',
#    'in',
#    'celebrities',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    ',',
#    'your',
#    'husband',
#    ',',
#    'am',
#    'going',
#    'to',
#    'have',
#    'lunch',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'use',
#    'a',
#    'guidebook',
#    'and',
#    'the',
#    'internet',
#    'when',
#    'I',
#    'prepare',
#    'for',
#    'a',
#    'trip',
#    '.',
#    '<end>'],
#   ['<start>',
#    'One',
#    'of',
#    'the',
#    'parents',
#    'also',
#    'tag',
#    'along',
#    'with',
#    'the',
#    'child',
#    '.',
#    '<end>'],
#   ['<start>',
#    'If',
#    'he',
#    'is',
#    'the',
#    'main',
#    'actor',
#    ',',
#    'he',
#    'leads',
#    'the',
#    'plot',
#    'of',
#    'the',
#    'movie',
#    '.',
#    '<end>'],
#   ['<start>',
#    'And',
#    'we',
#    'go',
#    'on',
#    'a',
#    'field',
#    'trip',
#    'on',
#    'the',
#    'day',
#    'after',
#    'the',
#    'exam',
#    'is',
#    'done',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'dont',
#    'understand',
#    'why',
#    'you',
#    'do',
#    'this',
#    'to',
#    'me',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'don',
#    "'",
#    't',
#    'go',
#    'to',
#    'school',
#    'since',
#    'there',
#    'is',
#    'a',
#    'exam',
#    'tomorrow',
#    'as',
#    'well',
#    '.',
#    '<end>'],
#   ['<start>',
#    'So',
#    'those',
#    'who',
#    'have',
#    'less',
#    'income',
#    'are',
#    'going',
#    'to',
#    'the',
#    'Philippines',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'leave',
#    'present',
#    'secretely',
#    'on',
#    'Christmas',
#    'Eve',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'will',
#    'be',
#    'trained',
#    'in',
#    'Malaysia',
#    'next',
#    'year',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'go',
#    'to',
#    'Gangnam',
#    'to',
#    'have',
#    'a',
#    'gettogether',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'go',
#    'there',
#    'because',
#    'the',
#    'summer',
#    'beach',
#    'is',
#    'beautiful',
#    '.',
#    '<end>'],
#   ['<start>',
#    'Autumn',
#    'is',
#    'getting',
#    'deeper',
#    'in',
#    'Korea',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'am',
#    'going',
#    'to',
#    'travel',
#    'in',
#    'Taiwan',
#    'next',
#    'week',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'am',
#    'going',
#    'to',
#    'go',
#    'for',
#    'the',
#    'part',
#    'time',
#    'job',
#    'at',
#    'a',
#    'convenient',
#    'store',
#    '.',
#    '<end>'],
#   ['<start>',
#    'We',
#    'go',
#    'to',
#    'America',
#    'by',
#    'riding',
#    'a',
#    'magical',
#    'carpet',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'go',
#    'hiking',
#    'to',
#    'a',
#    'mountain',
#    'with',
#    'my',
#    'husband',
#    'on',
#    'weekends',
#    '.',
#    '<end>'],
#   ['<start>',
#    'Friday',
#    'is',
#    'my',
#    'birthday',
#    ',',
#    'so',
#    'I',
#    'am',
#    'going',
#    'to',
#    'get',
#    'some',
#    'pizza',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'am',
#    'going',
#    'to',
#    'your',
#    'country',
#    'this',
#    'week',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'am',
#    'going',
#    'to',
#    'Vietnam',
#    'next',
#    'weekend',
#    'or',
#    'early',
#    'next',
#    'week',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'go',
#    'to',
#    'a',
#    'theater',
#    'from',
#    'time',
#    'to',
#    'time',
#    'to',
#    'see',
#    'a',
#    'musical',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'go',
#    'to',
#    'a',
#    'mountain',
#    'to',
#    'find',
#    'my',
#    'values',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'go',
#    'to',
#    'the',
#    'dance',
#    'class',
#    'after',
#    'going',
#    'to',
#    'the',
#    'beauty',
#    'shop',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'am',
#    'packing',
#    'my',
#    'clothes',
#    'in',
#    'my',
#    'bag',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'am',
#    'going',
#    'back',
#    'after',
#    'bringing',
#    'back',
#    'Kim',
#    '.',
#    '<end>'],
#   ['<start>',
#    'My',
#    'brother',
#    'goes',
#    'jogging',
#    'to',
#    'the',
#    'park',
#    'on',
#    'Sundays',
#    '.',
#    '<end>'],
#   ['<start>',
#    'And',
#    'I',
#    "'",
#    'm',
#    'going',
#    'to',
#    'the',
#    'airport',
#    'to',
#    'meet',
#    'you',
#    '.',
#    '<end>'],
#   ['<start>',
#    'We',
#    'usally',
#    'go',
#    'to',
#    'high',
#    'school',
#    'to',
#    'go',
#    'to',
#    'university',
#    '.',
#    '<end>'],
#   ['<start>',
#    'After',
#    'school',
#    'and',
#    'academy',
#    ',',
#    'I',
#    'go',
#    'back',
#    'to',
#    'my',
#    'home',
#    'at',
#    'late',
#    'night',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'feel',
#    'like',
#    'times',
#    'flies',
#    'when',
#    'I',
#    'am',
#    'with',
#    'you',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'work',
#    'on',
#    'Saturday',
#    'and',
#    'I',
#    'go',
#    'to',
#    'the',
#    'church',
#    'on',
#    'Sunday',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    "'",
#    'm',
#    'here',
#    'to',
#    'give',
#    'you',
#    ',',
#    'but',
#    'I',
#    'only',
#    'receive',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    "'",
#    'm',
#    'almost',
#    'done',
#    'preparing',
#    'for',
#    'a',
#    'business',
#    'in',
#    'the',
#    'Philippines',
#    '.',
#    '<end>'],
#   ['<start>',
#    'His',
#    'sister',
#    'goes',
#    'to',
#    'school',
#    'by',
#    'bus',
#    'everyday',
#    '.',
#    '<end>'],
#   ['<start>',
#    'And',
#    'I',
#    'will',
#    'go',
#    'to',
#    'Lotte',
#    'world',
#    'tomorrow',
#    '.',
#    '<end>'],
#   ['<start>',
#    'Muslims',
#    'go',
#    'to',
#    'traditional',
#    'market',
#    'on',
#    'fasting',
#    'period',
#    '.',
#    '<end>'],
#   ['<start>',
#    'Haneul',
#    ',',
#    'daddy',
#    "'",
#    's',
#    'coming',
#    'home',
#    'late',
#    'today',
#    '.',
#    '<end>'],
#   ['<start>',
#    'Everyone',
#    'become',
#    'children',
#    'on',
#    'snowy',
#    'day',
#    '.',
#    '<end>'],
#   ['<start>', 'Korean', 'foods', 'have', 'been', 'westernized', '.', '<end>'],
#   ['<start>',
#    'Most',
#    'of',
#    'my',
#    'friends',
#    'are',
#    'going',
#    'next',
#    'week',
#    '.',
#    '<end>'],
#   ['<start>',
#    'High',
#    'school',
#    'students',
#    'enter',
#    'colleges',
#    'after',
#    'graduation',
#    '.',
#    '<end>'],
#   ['<start>',
#    'Most',
#    'people',
#    'do',
#    'it',
#    'as',
#    'a',
#    'joke',
#    ',',
#    'so',
#    'we',
#    'just',
#    'laugh',
#    'it',
#    'off',
#    '.',
#    '<end>'],
#   ['<start>',
#    'Tomorrow',
#    ',',
#    'I',
#    "'",
#    'll',
#    'go',
#    'to',
#    'hospital',
#    'to',
#    'check',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'will',
#    'finish',
#    'the',
#    'job',
#    'and',
#    'go',
#    'home',
#    'soon',
#    '.',
#    '<end>'],
#   ['<start>',
#    'Then',
#    'I',
#    'go',
#    'to',
#    'do',
#    'aerobic',
#    'exercises',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    "'",
#    'll',
#    'go',
#    'to',
#    'France',
#    'certainly',
#    'if',
#    'I',
#    'can',
#    'afford',
#    'to',
#    'do',
#    'it',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'go',
#    'shopping',
#    'for',
#    'my',
#    'clothes',
#    'three',
#    'times',
#    'a',
#    'month',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'am',
#    'going',
#    'to',
#    'Japan',
#    'to',
#    'sell',
#    'my',
#    'body',
#    'for',
#    'making',
#    'money',
#    '.',
#    '<end>'],
#   ['<start>',
#    'A',
#    'lot',
#    'of',
#    'people',
#    'go',
#    'into',
#    'a',
#    'city',
#    'to',
#    'work',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'go',
#    'to',
#    'a',
#    'park',
#    'to',
#    'eat',
#    'a',
#    'sandwich',
#    'for',
#    'lunch',
#    '.',
#    '<end>'],
#   ['<start>',
#    'We',
#    'are',
#    'going',
#    'to',
#    'Singapore',
#    'at',
#    'the',
#    'end',
#    'of',
#    'March',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'suspect',
#    'about',
#    'the',
#    'cause',
#    'of',
#    'disability',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'am',
#    'going',
#    'to',
#    'Ulsan',
#    'to',
#    'take',
#    'an',
#    'exam',
#    'now',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'go',
#    'there',
#    'to',
#    'walk',
#    'as',
#    'an',
#    'exercise',
#    '.',
#    '<end>'],
#   ['<start>',
#    'We',
#    'continue',
#    'to',
#    'make',
#    'our',
#    'own',
#    'new',
#    'road',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'had',
#    'so',
#    'much',
#    'great',
#    'memories',
#    'thanks',
#    'to',
#    'you',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'go',
#    'to',
#    'that',
#    'school',
#    'alone',
#    'in',
#    'my',
#    'school',
#    '.',
#    '<end>'],
#   ['<start>',
#    'Many',
#    'foreigners',
#    'go',
#    'to',
#    'Seoul',
#    'every',
#    'year',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'came',
#    'yesterday',
#    'and',
#    'I',
#    'will',
#    'leave',
#    'today',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'often',
#    'go',
#    'to',
#    'outback',
#    'with',
#    'Ashley',
#    '.',
#    '<end>'],
#   ['<start>',
#    'Next',
#    'week',
#    'you',
#    'will',
#    'go',
#    'there',
#    'with',
#    'me',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'occasionally',
#    'go',
#    'for',
#    'a',
#    'walk',
#    'to',
#    'Olympic',
#    'park',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    "'",
#    'm',
#    'going',
#    'to',
#    'choir',
#    'practice',
#    'tomorrow',
#    'morning',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'don',
#    "'",
#    't',
#    'understand',
#    'why',
#    'people',
#    'relate',
#    'art',
#    'to',
#    'sexuality',
#    '.',
#    '<end>'],
#   ['<start>',
#    'Ten',
#    'out',
#    'of',
#    'eight',
#    'Korean',
#    'student',
#    'go',
#    'to',
#    'the',
#    'college',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'go',
#    'to',
#    'the',
#    'dermatology',
#    'because',
#    'of',
#    'my',
#    'pimples',
#    '.',
#    '<end>'],
#   ['<start>',
#    'And',
#    'I',
#    "'",
#    'll',
#    'go',
#    'to',
#    'sister',
#    "'",
#    's',
#    'house',
#    'in',
#    'the',
#    'evening',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'will',
#    'make',
#    'sure',
#    'to',
#    'go',
#    'to',
#    'Vietnam',
#    'this',
#    'week',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'will',
#    'be',
#    'going',
#    'to',
#    'New',
#    'York',
#    'on',
#    'Wendsday',
#    'with',
#    'my',
#    'son',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'really',
#    'learned',
#    'a',
#    'lot',
#    'of',
#    'things',
#    'from',
#    'the',
#    'Philippines',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    "'",
#    'm',
#    'going',
#    'to',
#    'do',
#    'skydiving',
#    'on',
#    'January',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    "'",
#    'm',
#    'going',
#    'to',
#    'swim',
#    'at',
#    'the',
#    'swimming',
#    'pool',
#    'and',
#    'get',
#    'some',
#    'lunch',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    "'",
#    'm',
#    'always',
#    'taking',
#    'firecrackers',
#    'when',
#    'I',
#    'go',
#    'to',
#    'the',
#    'beach',
#    '.',
#    '<end>'],
#   ['<start>',
#    'Jill',
#    'goes',
#    'to',
#    'see',
#    'her',
#    'grandmother',
#    'once',
#    'a',
#    'week',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'get',
#    'up',
#    'early',
#    'and',
#    'go',
#    'to',
#    'the',
#    'church',
#    'on',
#    'Sunday',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'go',
#    'to',
#    'Gunsan',
#    'port',
#    'everytime',
#    'whenever',
#    'the',
#    'ship',
#    'comes',
#    'in',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    "'",
#    'm',
#    'going',
#    'back',
#    'to',
#    'my',
#    'country',
#    'this',
#    'thursday',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'go',
#    'abroad',
#    'for',
#    'a',
#    'language',
#    'training',
#    'on',
#    'January',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    "'",
#    'm',
#    'going',
#    'to',
#    'reserved',
#    'army',
#    'drill',
#    'this',
#    'week',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'often',
#    'go',
#    'to',
#    'the',
#    'department',
#    'store',
#    'to',
#    'buy',
#    'stuffs',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'go',
#    'to',
#    'the',
#    'billard',
#    'hall',
#    'every',
#    'weekend',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'go',
#    'to',
#    'the',
#    'USA',
#    'for',
#    'holidays',
#    'in',
#    'September',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    "'",
#    'm',
#    'going',
#    'to',
#    'the',
#    'Philippines',
#    'to',
#    'meet',
#    'you',
#    '.',
#    '<end>'],
#   ['<start>',
#    'Every',
#    'morning',
#    ',',
#    'I',
#    'drive',
#    'to',
#    'the',
#    'pool',
#    'to',
#    'go',
#    'for',
#    'swimming',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'am',
#    'going',
#    'to',
#    'visit',
#    'my',
#    'daughter',
#    'in',
#    'America',
#    'for',
#    'one',
#    'month',
#    '.',
#    '<end>'],
#   ['<start>',
#    'He',
#    'will',
#    'go',
#    'to',
#    'Cambodia',
#    'in',
#    'this',
#    'week',
#    '.',
#    '<end>'],
#   ['<start>',
#    'He',
#    'usually',
#    'goes',
#    'to',
#    'the',
#    'park',
#    'twice',
#    'a',
#    'week',
#    '.',
#    '<end>'],
#   ['<start>',
#    'Then',
#    ',',
#    'I',
#    'go',
#    'to',
#    'Vietnam',
#    'alone',
#    'this',
#    'time',
#    '.',
#    '<end>'],
#   ['<start>',
#    'And',
#    'I',
#    'am',
#    'going',
#    'to',
#    'get',
#    'the',
#    'car',
#    'back',
#    'in',
#    'the',
#    'afternoon',
#    '.',
#    '<end>'],
#   ['<start>',
#    'She',
#    'takes',
#    'a',
#    'train',
#    'from',
#    'Seoul',
#    'to',
#    'Pusan',
#    '.',
#    '<end>'],
#   ['<start>',
#    'We',
#    'go',
#    'to',
#    'Atlanta',
#    'during',
#    'the',
#    'weekend',
#    '.',
#    '<end>'],
#   ['<start>',
#    'The',
#    'whole',
#    'company',
#    'goes',
#    'to',
#    'hiking',
#    'in',
#    'fall',
#    '.',
#    '<end>'],
#   ['<start>',
#    'We',
#    'came',
#    'to',
#    'school',
#    'and',
#    'we',
#    "'",
#    're',
#    'going',
#    'to',
#    'watch',
#    'a',
#    'film',
#    '.',
#    '<end>'],
#   ['<start>',
#    'The',
#    'professor',
#    'invited',
#    'us',
#    ',',
#    'so',
#    'we',
#    'are',
#    'going',
#    'to',
#    'his',
#    'house',
#    '.',
#    '<end>'],
#   ['<start>',
#    'Ride',
#    'a',
#    'car',
#    'for',
#    'two',
#    'hours',
#    'from',
#    'Manila',
#    'Airport',
#    '.',
#    '<end>'],
#   ['<start>',
#    'But',
#    'I',
#    'learned',
#    'many',
#    'things',
#    'from',
#    'you',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'will',
#    'go',
#    'to',
#    'the',
#    'retreat',
#    'with',
#    'friends',
#    'to',
#    'Gyungju',
#    'tomorrow',
#    '.',
#    '<end>'],
#   ['<start>',
#    'Today',
#    'I',
#    'go',
#    'to',
#    'Japan',
#    'to',
#    'see',
#    'my',
#    'sister',
#    'living',
#    'there',
#    '.',
#    '<end>'],
#   ['<start>',
#    'If',
#    'you',
#    'are',
#    'not',
#    'able',
#    'to',
#    'come',
#    'to',
#    'Korea',
#    ',',
#    'I',
#    'will',
#    'go',
#    'to',
#    'Thailand',
#    '.',
#    '<end>'],
#   ['<start>',
#    'We',
#    'will',
#    'travel',
#    'after',
#    'my',
#    'husband',
#    'comes',
#    'back',
#    'from',
#    'Korea',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    "'",
#    'll',
#    'come',
#    'on',
#    'Friday',
#    'night',
#    'and',
#    'leave',
#    'on',
#    'Sunday',
#    'night',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'go',
#    'to',
#    'the',
#    'office',
#    'on',
#    'Sunday',
#    'afternoon',
#    '.',
#    '<end>'],
#   ['<start>',
#    'About',
#    'eight',
#    'hours',
#    'on',
#    'a',
#    'full',
#    'charge',
#    '.',
#    '<end>'],
#   ['<start>',
#    'And',
#    'left',
#    'England',
#    'on',
#    'the',
#    'Eurostar',
#    'from',
#    'London',
#    'to',
#    'Germany',
#    '.',
#    '<end>'],
#   ['<start>',
#    'Even',
#    'if',
#    'it',
#    'rains',
#    ',',
#    'we',
#    "'",
#    're',
#    'still',
#    'going',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'am',
#    'flying',
#    'to',
#    'China',
#    'on',
#    'a',
#    'Korean',
#    'Airlines',
#    'flight',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'am',
#    'going',
#    'to',
#    'Korea',
#    'in',
#    'order',
#    'to',
#    'register',
#    'my',
#    'baby',
#    "'",
#    's',
#    'birth',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'go',
#    'shopping',
#    'about',
#    'twice',
#    'a',
#    'month',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'often',
#    'go',
#    'to',
#    'the',
#    'ballpark',
#    'and',
#    'watch',
#    'games',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'ride',
#    'the',
#    'bicycle',
#    'to',
#    'the',
#    'station',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'usually',
#    'visit',
#    'relatives',
#    'during',
#    'the',
#    'New',
#    'Year',
#    'Holidays',
#    '.',
#    '<end>'],
#   ['<start>',
#    'Its',
#    'crease',
#    'is',
#    'smaller',
#    'than',
#    'other',
#    'equivalent',
#    'fabrics',
#    '.',
#    '<end>'],
#   ['<start>',
#    'Let',
#    "'",
#    's',
#    'go',
#    'and',
#    'have',
#    'a',
#    'cup',
#    'of',
#    'coffee',
#    'sometime',
#    '.',
#    '<end>'],
#   ['<start>',
#    'Let',
#    "'",
#    's',
#    'go',
#    'to',
#    'Hawaii',
#    'during',
#    'summer',
#    'vacation',
#    '.',
#    '<end>'],
#   ['<start>',
#    'Most',
#    'of',
#    'the',
#    'graduates',
#    'of',
#    'my',
#    'high',
#    'school',
#    'go',
#    'to',
#    'the',
#    'university',
#    '.',
#    '<end>'],
#   ['<start>',
#    'My',
#    'adventure',
#    'story',
#    'goes',
#    'to',
#    'a',
#    'new',
#    'world',
#    ',',
#    'overcoming',
#    'fear',
#    '.',
#    '<end>'],
#   ['<start>',
#    'No',
#    ',',
#    'I',
#    "'",
#    'll',
#    'be',
#    'in',
#    'Tokyo',
#    'to',
#    'meet',
#    'clients',
#    '.',
#    '<end>'],
#   ['<start>',
#    'Not',
#    'always',
#    ',',
#    'I',
#    'usually',
#    'go',
#    'to',
#    'café',
#    'when',
#    'I',
#    'meet',
#    'friends',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'paint',
#    'with',
#    'many',
#    'friends',
#    'and',
#    'go',
#    'to',
#    'galleries',
#    '.',
#    '<end>'],
#   ['<start>',
#    'We',
#    'collect',
#    'pool',
#    'money',
#    'with',
#    'friends',
#    'to',
#    'covering',
#    'expenses',
#    '.',
#    '<end>'],
#   ['<start>',
#    'So',
#    'people',
#    'who',
#    'visit',
#    'Busan',
#    'should',
#    'go',
#    'there',
#    'and',
#    'take',
#    'pictures',
#    '.',
#    '<end>'],
#   ['<start>',
#    'This',
#    'person',
#    'will',
#    'go',
#    'to',
#    'Myungdong',
#    'with',
#    'us',
#    'by',
#    'car',
#    '.',
#    '<end>'],
#   ['<start>',
#    'This',
#    'plane',
#    'goes',
#    'through',
#    'Warsaw',
#    'to',
#    'Köln',
#    '.',
#    '<end>'],
#   ['<start>',
#    'Tomorrow',
#    ',',
#    'I',
#    "'",
#    'm',
#    'going',
#    'to',
#    'Pullman',
#    'for',
#    'three',
#    'days',
#    'with',
#    'a',
#    'friend',
#    '.',
#    '<end>'],
#   ['<start>',
#    'Turn',
#    'left',
#    'at',
#    'the',
#    'second',
#    'signal',
#    'light',
#    '.',
#    '<end>'],
#   ['<start>',
#    'We',
#    'often',
#    'go',
#    'for',
#    'drinks',
#    'with',
#    'colleagues',
#    'after',
#    'work',
#    '.',
#    '<end>'],
#   ['<start>',
#    'Whenever',
#    'I',
#    'want',
#    'to',
#    'research',
#    'something',
#    ',',
#    'I',
#    'go',
#    'to',
#    'the',
#    'library',
#    '.',
#    '<end>'],
#   ['<start>',
#    'If',
#    'the',
#    'fine',
#    'is',
#    'determined',
#    ',',
#    'the',
#    'bill',
#    'will',
#    'be',
#    'sent',
#    'to',
#    'you',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    "'",
#    'm',
#    'now',
#    'going',
#    'to',
#    'Vancouver',
#    'by',
#    'the',
#    'Korean',
#    'Air',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    "'",
#    'm',
#    'interested',
#    'in',
#    'education',
#    'and',
#    'employment',
#    'news',
#    '.',
#    '<end>'],
#   ['<start>',
#    'He',
#    'goes',
#    'to',
#    'Starbucks',
#    'to',
#    'drink',
#    'coffee',
#    '.',
#    '<end>'],
#   ['<start>',
#    'My',
#    'dad',
#    'is',
#    'making',
#    'a',
#    'zoo',
#    'in',
#    'my',
#    'house',
#    ',',
#    'along',
#    'with',
#    'KkomKkomi',
#    '.',
#    '<end>'],
#   ['<start>',
#    'After',
#    'volunteer',
#    'work',
#    ',',
#    'I',
#    'learned',
#    'many',
#    'lessons',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'plan',
#    'to',
#    'visit',
#    'Japan',
#    'this',
#    'weekend',
#    '.',
#    '<end>'],
#   ['<start>',
#    'The',
#    'darker',
#    'the',
#    'sky',
#    'above',
#    ',',
#    'the',
#    'brighter',
#    'the',
#    'sky',
#    'in',
#    'my',
#    'hand',
#    '.',
#    '<end>'],
#   ['<start>',
#    'We',
#    'leave',
#    'the',
#    'key',
#    'and',
#    'the',
#    'money',
#    'on',
#    'the',
#    'table',
#    'as',
#    'promised',
#    '.',
#    '<end>'],
#   ['<start>',
#    'We',
#    'can',
#    'imagine',
#    'how',
#    'upset',
#    'this',
#    'would',
#    'have',
#    'made',
#    'you',
#    '.',
#    '<end>'],
#   ['<start>',
#    'My',
#    'train',
#    'goes',
#    'to',
#    'Detroit',
#    'through',
#    'Chicago',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'usually',
#    'go',
#    'to',
#    'work',
#    'at',
#    'eight',
#    'thirty',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'go',
#    'to',
#    'cram',
#    'school',
#    'three',
#    'times',
#    'a',
#    'week',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'usually',
#    'go',
#    'to',
#    'the',
#    'office',
#    'at',
#    'eight',
#    'thirty',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    "'",
#    'm',
#    'going',
#    'back',
#    'to',
#    'Japan',
#    'on',
#    'the',
#    'fifth',
#    'of',
#    'next',
#    'month',
#    '.',
#    '<end>'],
#   ['<start>',
#    'This',
#    'suit',
#    'doesn',
#    "'",
#    't',
#    'fit',
#    'well',
#    'and',
#    'it',
#    "'",
#    's',
#    'faded',
#    'in',
#    'the',
#    'bargain',
#    '.',
#    '<end>'],
#   ['<start>',
#    'This',
#    'clock',
#    'gains',
#    'more',
#    'than',
#    'five',
#    'minutes',
#    'a',
#    'day',
#    '.',
#    '<end>'],
#   ['<start>',
#    'We',
#    "'",
#    're',
#    'descending',
#    'the',
#    'river',
#    'on',
#    'a',
#    'pleasure',
#    'boat',
#    '.',
#    '<end>'],
#   ['<start>',
#    'Let',
#    "'",
#    's',
#    'go',
#    'to',
#    'a',
#    'Japanese',
#    'restaurant',
#    'for',
#    'dinner',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'often',
#    'go',
#    'for',
#    'walks',
#    'in',
#    'the',
#    'park',
#    'near',
#    'my',
#    'home',
#    '.',
#    '<end>'],
#   ['<start>',
#    'Thank',
#    'you',
#    'for',
#    'the',
#    'nice',
#    'tea',
#    'and',
#    'a',
#    'pleasant',
#    'time',
#    '.',
#    '<end>'],
#   ['<start>',
#    'Oh',
#    ',',
#    'I',
#    "'",
#    'm',
#    'sorry',
#    ',',
#    'but',
#    'I',
#    "'",
#    'm',
#    'going',
#    'to',
#    'Chicago',
#    'today',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'go',
#    'there',
#    'twice',
#    'a',
#    'month',
#    'or',
#    'so',
#    'and',
#    'let',
#    'off',
#    'steam',
#    '.',
#    '<end>'],
#   ['<start>',
#    'Video',
#    'game',
#    'wizards',
#    'can',
#    'make',
#    'it',
#    'to',
#    'the',
#    'highest',
#    'level',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'go',
#    'to',
#    'bed',
#    'when',
#    'electricity',
#    'is',
#    'shut',
#    'down',
#    'at',
#    'night',
#    '.',
#    '<end>'],
#   ['<start>',
#    'Your',
#    'explanation',
#    'doesn',
#    "'",
#    't',
#    'convince',
#    'me',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    "'",
#    'm',
#    'trying',
#    ',',
#    'and',
#    'I',
#    'go',
#    'to',
#    'the',
#    'library',
#    'every',
#    'day',
#    '.',
#    '<end>'],
#   ['<start>',
#    'Yes',
#    ',',
#    'I',
#    'take',
#    'a',
#    'long',
#    'summer',
#    'vacation',
#    'and',
#    'go',
#    'windsurfing',
#    '.',
#    '<end>'],
#   ['<start>',
#    'Yes',
#    ',',
#    'I',
#    'go',
#    'to',
#    'a',
#    'driving',
#    'range',
#    'once',
#    'a',
#    'week',
#    'or',
#    'so',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'go',
#    'to',
#    'the',
#    'ballet',
#    'once',
#    'or',
#    'twice',
#    'a',
#    'year',
#    '.',
#    '<end>'],
#   ['<start>',
#    'He',
#    'always',
#    'goes',
#    'home',
#    'as',
#    'soon',
#    'as',
#    'his',
#    'work',
#    'is',
#    'over',
#    '.',
#    '<end>'],
#   ['<start>',
#    'She',
#    "'",
#    's',
#    'getting',
#    'more',
#    'and',
#    'more',
#    'popular',
#    '.',
#    '<end>'],
#   ['<start>',
#    'He',
#    'is',
#    'looking',
#    'more',
#    'alike',
#    'as',
#    'he',
#    'grows',
#    'up',
#    '.',
#    '<end>'],
#   ['<start>',
#    'Time',
#    'goes',
#    'by',
#    'slowly',
#    ',',
#    'if',
#    'you',
#    'save',
#    'it',
#    '.',
#    '<end>'],
#   ['<start>',
#    'Lots',
#    'of',
#    'Korean',
#    'goes',
#    'there',
#    'for',
#    'honeymoon',
#    '?',
#    '<end>'],
#   ['<start>',
#    'Do',
#    'Korean',
#    'high',
#    'school',
#    'students',
#    'go',
#    'to',
#    'school',
#    'during',
#    'breaks',
#    '?',
#    '<end>'],
#   ['<start>',
#    'Thank',
#    'you',
#    ',',
#    'but',
#    'Can',
#    "'",
#    't',
#    'you',
#    'go',
#    'next',
#    'week',
#    '?',
#    '<end>'],
#   ['<start>',
#    'Are',
#    'we',
#    'going',
#    'on',
#    'a',
#    'vacation',
#    'to',
#    'Cambodia',
#    'together',
#    '?',
#    '<end>'],
#   ['<start>',
#    'Don',
#    "'",
#    't',
#    'you',
#    'go',
#    'to',
#    'the',
#    'restaurant',
#    'at',
#    'morning',
#    'in',
#    'Korea',
#    '?',
#    '<end>'],
#   ['<start>',
#    'Am',
#    'I',
#    'going',
#    'to',
#    'help',
#    'my',
#    'friend',
#    'today',
#    '?',
#    '<end>'],
#   ['<start>',
#    'Go',
#    'to',
#    'serak',
#    'mountain',
#    'with',
#    'church',
#    'friends',
#    'today',
#    '?',
#    '<end>'],
#   ['<start>',
#    'Are',
#    'you',
#    'going',
#    'to',
#    'immigration',
#    'office',
#    'today',
#    'for',
#    'an',
#    'education',
#    '?',
#    '<end>'],
#   ['<start>',
#    'Have',
#    'we',
#    'been',
#    'together',
#    'for',
#    'almost',
#    'two',
#    'years',
#    '?',
#    '<end>'],
#   ['<start>',
#    'Are',
#    'you',
#    'going',
#    'to',
#    'Myanmar',
#    'instead',
#    'of',
#    'China',
#    'this',
#    'break',
#    '?',
#    '<end>'],
#   ['<start>',
#    'Is',
#    'Sarah',
#    'attending',
#    'the',
#    'party',
#    'next',
#    'Friday',
#    '?',
#    '<end>'],
#   ['<start>',
#    'Where',
#    'can',
#    'I',
#    'ride',
#    'the',
#    'Window',
#    'of',
#    'the',
#    'World',
#    'Train',
#    '?',
#    '<end>'],
#   ['<start>',
#    'So',
#    'are',
#    'you',
#    'going',
#    'to',
#    'go',
#    'back',
#    'to',
#    'Korea',
#    'on',
#    'Sunday',
#    'at',
#    'lunch',
#    'time',
#    '?',
#    '<end>'],
#   ['<start>',
#    'So',
#    ',',
#    'you',
#    'only',
#    'go',
#    'there',
#    'once',
#    'a',
#    'week',
#    '?',
#    '<end>'],
#   ['<start>',
#    'How',
#    'many',
#    'times',
#    'do',
#    'you',
#    'go',
#    'to',
#    'the',
#    'market',
#    'every',
#    'week',
#    '?',
#    '<end>'],
#   ['<start>',
#    'Are',
#    'you',
#    'going',
#    'traveling',
#    'this',
#    'Sunday',
#    'and',
#    'Monday',
#    '?',
#    '<end>'],
#   ['<start>',
#    'Do',
#    'you',
#    'know',
#    'how',
#    'to',
#    'drink',
#    'wine',
#    'and',
#    'really',
#    'taste',
#    'it',
#    '?',
#    '<end>'],
#   ['<start>',
#    'Maybe',
#    'he',
#    'already',
#    'went',
#    'back',
#    'home',
#    'a',
#    'while',
#    'ago',
#    '?',
#    '<end>'],
#   ['<start>',
#    'Are',
#    'you',
#    'going',
#    'to',
#    'Canada',
#    'with',
#    'a',
#    'working',
#    'holiday',
#    'visa',
#    '?',
#    '<end>'],
#   ['<start>',
#    'Is',
#    'Daniel',
#    'absent',
#    'from',
#    'school',
#    'due',
#    'to',
#    'his',
#    'bad',
#    'condition',
#    '?',
#    '<end>'],
#   ['<start>',
#    'Are',
#    'you',
#    'on',
#    'your',
#    'way',
#    'to',
#    'buy',
#    'a',
#    'pen',
#    'or',
#    'a',
#    'notebook',
#    '?',
#    '<end>'],
#   ['<start>',
#    'How',
#    'do',
#    'you',
#    'call',
#    'a',
#    'person',
#    'who',
#    'steals',
#    'cars',
#    'in',
#    'English',
#    '?',
#    '<end>'],
#   ['<start>',
#    'And',
#    'then',
#    'will',
#    'you',
#    'go',
#    'back',
#    'to',
#    'England',
#    '?',
#    '<end>'],
#   ['<start>',
#    'Are',
#    'you',
#    'eaving',
#    'with',
#    'good',
#    'memories',
#    'from',
#    'Taiwan',
#    '?',
#    '<end>'],
#   ['<start>',
#    'Mom',
#    ',',
#    'are',
#    'yourts',
#    'and',
#    'fruits',
#    'running',
#    'out',
#    'at',
#    'your',
#    'home',
#    '?',
#    '<end>'],
#   ['<start>',
#    'Do',
#    'you',
#    'go',
#    'to',
#    'taekwondo',
#    'after',
#    'you',
#    'come',
#    'home',
#    'and',
#    'have',
#    'a',
#    'meal',
#    '?',
#    '<end>'],
#   ['<start>',
#    'I',
#    'visited',
#    'my',
#    'relatives',
#    'and',
#    'now',
#    'I',
#    'am',
#    'going',
#    'back',
#    '?',
#    '<end>'],
#   ['<start>',
#    'Will',
#    'you',
#    'go',
#    'with',
#    'me',
#    'when',
#    'I',
#    'go',
#    'to',
#    'the',
#    'Venis',
#    '?',
#    '<end>'],
#   ['<start>',
#    'Why',
#    'do',
#    'I',
#    'always',
#    'make',
#    'mistakes',
#    'in',
#    'front',
#    'of',
#    'her',
#    '?',
#    '<end>'],
#   ['<start>',
#    'Next',
#    'time',
#    'I',
#    'come',
#    'to',
#    'Korea',
#    ',',
#    'let',
#    "'",
#    's',
#    'go',
#    'snow',
#    'boarding',
#    'together',
#    '?',
#    '<end>'],
#   ['<start>',
#    'Do',
#    'you',
#    'go',
#    'to',
#    'the',
#    'water',
#    'park',
#    'if',
#    'you',
#    'come',
#    'to',
#    'Korea',
#    'in',
#    'Summer',
#    '?',
#    '<end>'],
#   ['<start>',
#    'Are',
#    'they',
#    'going',
#    'to',
#    'sing',
#    'and',
#    'dance',
#    'at',
#    'the',
#    'party',
#    '?',
#    '<end>'],
#   ['<start>',
#    'Has',
#    'she',
#    'not',
#    'sent',
#    'the',
#    'amount',
#    'for',
#    'the',
#    'product',
#    'yet',
#    '?',
#    '<end>'],
#   ['<start>',
#    'More',
#    'importantly',
#    ',',
#    'how',
#    'about',
#    'you',
#    'stop',
#    'pointing',
#    'a',
#    'gun',
#    'at',
#    'me',
#    '?',
#    '<end>'],
#   ['<start>',
#    'What',
#    'comes',
#    'to',
#    'your',
#    'mind',
#    'when',
#    'you',
#    'hear',
#    'the',
#    'word',
#    'Americhino',
#    '?',
#    '<end>'],
#   ['<start>',
#    'When',
#    "'",
#    's',
#    'the',
#    'next',
#    'flight',
#    'to',
#    'Pennsylvania',
#    '?',
#    '<end>'],
#   ['<start>',
#    'Turn',
#    'right',
#    ',',
#    'and',
#    'two',
#    'hundred',
#    'meters',
#    '?',
#    '<end>'],
#   ['<start>',
#    'This',
#    'isn',
#    "'",
#    't',
#    'the',
#    'Partridge',
#    'residence',
#    '?',
#    '<end>'],
#   ['<start>',
#    'How',
#    'often',
#    'do',
#    'the',
#    'trains',
#    'run',
#    'to',
#    'Ueno',
#    '?',
#    '<end>'],
#   ['<start>',
#    'Is',
#    'educational',
#    'background',
#    'important',
#    'in',
#    'your',
#    'country',
#    '?',
#    '<end>'],
#   ['<start>',
#    'Are',
#    'there',
#    'many',
#    'single',
#    'mothers',
#    'in',
#    'your',
#    'country',
#    '?',
#    '<end>'],
#   ['<start>',
#    'Is',
#    'it',
#    'impolite',
#    'to',
#    'speak',
#    'to',
#    'strangers',
#    '?',
#    '<end>'],
#   ['<start>',
#    'Let',
#    "'",
#    's',
#    'take',
#    'him',
#    'somewhere',
#    'very',
#    'Japanese',
#    ',',
#    'like',
#    'Mount',
#    'Fuji',
#    '.',
#    '<end>'],
#   ['<start>',
#    'Let',
#    "'",
#    's',
#    'call',
#    'it',
#    'a',
#    'day',
#    'and',
#    'go',
#    'to',
#    'our',
#    'reception',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'only',
#    'go',
#    'shopping',
#    'when',
#    'I',
#    'need',
#    'to',
#    'buy',
#    'a',
#    'gift',
#    'for',
#    'someone',
#    '.',
#    '<end>'],
#   ['<start>',
#    'So',
#    'tonight',
#    ',',
#    'let',
#    "'",
#    's',
#    'go',
#    'out',
#    'for',
#    'a',
#    'drink',
#    '.',
#    '<end>'],
#   ['<start>',
#    'Where',
#    'do',
#    'we',
#    'need',
#    'to',
#    'go',
#    'to',
#    'the',
#    'sea',
#    '?',
#    '<end>'],
#   ['<start>',
#    'How',
#    'can',
#    'I',
#    'get',
#    'to',
#    'your',
#    'house',
#    'from',
#    'the',
#    'airport',
#    '?',
#    '<end>'],
#   ['<start>',
#    'How',
#    'can',
#    'I',
#    'get',
#    'to',
#    'Darlington',
#    'Square',
#    '?',
#    '<end>'],
#   ['<start>',
#    'There',
#    'are',
#    'two',
#    'benefits',
#    'of',
#    'using',
#    'online',
#    'shopping',
#    '.',
#    '<end>'],
#   ['<start>',
#    'Do',
#    'we',
#    'go',
#    'together',
#    'by',
#    'our',
#    'car',
#    'after',
#    'work',
#    '?',
#    '<end>'],
#   ['<start>',
#    'Why',
#    'don',
#    "'",
#    't',
#    'we',
#    'go',
#    'on',
#    'a',
#    'spring',
#    'break',
#    'as',
#    'the',
#    'weather',
#    'is',
#    'so',
#    'warm',
#    '?',
#    '<end>'],
#   ['<start>',
#    'Shall',
#    'we',
#    'go',
#    'Saturday',
#    'dawn',
#    'by',
#    'the',
#    'Korean',
#    'Air',
#    '?',
#    '<end>'],
#   ['<start>',
#    'What',
#    'kind',
#    'of',
#    'clothes',
#    'should',
#    'I',
#    'wear',
#    'to',
#    'go',
#    'to',
#    'the',
#    'meeting',
#    '?',
#    '<end>'],
#   ['<start>',
#    'Then',
#    'how',
#    'about',
#    'going',
#    'to',
#    'a',
#    'Japanese',
#    'restaurant',
#    'on',
#    'Sunday',
#    '?',
#    '<end>'],
#   ['<start>',
#    'So',
#    ',',
#    'What',
#    'time',
#    'will',
#    'we',
#    'go',
#    'on',
#    'Monday',
#    'or',
#    'Tuseday',
#    '?',
#    '<end>'],
#   ['<start>',
#    'Where',
#    'do',
#    'you',
#    'want',
#    'to',
#    'go',
#    'next',
#    'Friday',
#    '?',
#    '<end>'],
#   ['<start>',
#    'Darling',
#    ',',
#    'why',
#    'don',
#    "'",
#    't',
#    'we',
#    'go',
#    'to',
#    'Hongkong',
#    'this',
#    'summer',
#    '?',
#    '<end>'],
#   ['<start>',
#    'Shall',
#    'we',
#    'go',
#    'to',
#    'eat',
#    'pizza',
#    'together',
#    'on',
#    'Sunday',
#    '?',
#    '<end>'],
#   ['<start>',
#    'Shall',
#    'we',
#    'go',
#    'to',
#    'Osaka',
#    'Castle',
#    'since',
#    'we',
#    'had',
#    'lunch',
#    '?',
#    '<end>'],
#   ['<start>',
#    'If',
#    'it',
#    "'",
#    's',
#    'okay',
#    'for',
#    'you',
#    ',',
#    'should',
#    'I',
#    'go',
#    'to',
#    'your',
#    'house',
#    'for',
#    'a',
#    'moment',
#    '?',
#    '<end>'],
#   ['<start>',
#    'If',
#    'you',
#    'are',
#    'tired',
#    ',',
#    'I',
#    'want',
#    'to',
#    'go',
#    'home',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'want',
#    'to',
#    'go',
#    'to',
#    'new',
#    'zealand',
#    'next',
#    'weekend',
#    'to',
#    'do',
#    'bungee',
#    'jump',
#    '.',
#    '<end>'],
#   ['<start>',
#    'Then',
#    'do',
#    'you',
#    'want',
#    'to',
#    'eat',
#    'pasta',
#    'when',
#    'we',
#    'meet',
#    'later',
#    '?',
#    '<end>'],
#   ['<start>',
#    'But',
#    'I',
#    'went',
#    'swimming',
#    'after',
#    'practicing',
#    'hard',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'went',
#    'to',
#    'the',
#    'Phuket',
#    'Caorak',
#    'last',
#    'summer',
#    'vacation',
#    '.',
#    '<end>'],
#   ['<start>',
#    'He',
#    'went',
#    'back',
#    'to',
#    'military',
#    'since',
#    'the',
#    'vacation',
#    'was',
#    'over',
#    'by',
#    'today',
#    '.',
#    '<end>'],
#   ['<start>',
#    'His',
#    'family',
#    'was',
#    'on',
#    'trip',
#    'after',
#    'he',
#    'died',
#    '.',
#    '<end>'],
#   ['<start>',
#    'Then',
#    'afterwards',
#    'I',
#    'went',
#    'to',
#    'drink',
#    'coffee',
#    '.',
#    '<end>'],
#   ['<start>',
#    'We',
#    'went',
#    'to',
#    'the',
#    'beach',
#    'after',
#    'playing',
#    'soccer',
#    '.',
#    '<end>'],
#   ['<start>',
#    'After',
#    'all',
#    ',',
#    'the',
#    'two',
#    'plans',
#    'have',
#    'turned',
#    'out',
#    'to',
#    'be',
#    'failures',
#    '.',
#    '<end>'],
#   ['<start>',
#    'The',
#    'first',
#    'went',
#    'to',
#    'a',
#    'high',
#    'school',
#    'friend',
#    'of',
#    'the',
#    'industry',
#    'Office',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'went',
#    'to',
#    'Indonesia',
#    'for',
#    'my',
#    'missionary',
#    'work',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'went',
#    'Hwacheun',
#    'trout',
#    'festival',
#    'today',
#    '.',
#    '<end>'],
#   ['<start>',
#    'My',
#    'son',
#    'had',
#    'entered',
#    'the',
#    'army',
#    'on',
#    'Tuesday',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'went',
#    'to',
#    'Hong',
#    'kong',
#    'and',
#    'China',
#    'on',
#    'a',
#    'family',
#    'trip',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'went',
#    'to',
#    'my',
#    'cousin',
#    "'",
#    's',
#    'house',
#    'by',
#    'subway',
#    'for',
#    'myself',
#    'today',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'took',
#    'this',
#    'camera',
#    'for',
#    'school',
#    'field',
#    'trips',
#    'or',
#    'picnics',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'went',
#    'Kangwondo',
#    'with',
#    'my',
#    'friend',
#    'to',
#    'see',
#    'the',
#    'sunrise',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'went',
#    'to',
#    'a',
#    'marine',
#    'base',
#    'to',
#    'teach',
#    'English',
#    '.',
#    '<end>'],
#   ['<start>',
#    'My',
#    'sister',
#    'went',
#    'to',
#    'her',
#    'room',
#    'because',
#    'she',
#    'was',
#    'embarrassed',
#    '.',
#    '<end>'],
#   ['<start>',
#    'Arriving',
#    'at',
#    'Busan',
#    ',',
#    'our',
#    'family',
#    'went',
#    'to',
#    'the',
#    'beach',
#    'first',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'went',
#    'to',
#    'the',
#    'meat',
#    'restaurant',
#    'we',
#    'went',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'went',
#    'to',
#    'Jeju',
#    'on',
#    'a',
#    'vacation',
#    'with',
#    'my',
#    'family',
#    'last',
#    'year',
#    '.',
#    '<end>'],
#   ['<start>',
#    'Two',
#    'people',
#    'went',
#    'to',
#    'the',
#    'fountain',
#    'in',
#    'the',
#    'forest',
#    'together',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'finished',
#    'my',
#    'work',
#    'and',
#    'went',
#    'to',
#    'Lotte',
#    'mart',
#    'yesterday',
#    '.',
#    '<end>'],
#   ['<start>',
#    'At',
#    'that',
#    'time',
#    'I',
#    'went',
#    'to',
#    'the',
#    'country',
#    'to',
#    'see',
#    'grandmother',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'went',
#    'to',
#    'the',
#    'Han',
#    'River',
#    'to',
#    'get',
#    'some',
#    'fresh',
#    'air',
#    'yesterday',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'gave',
#    'it',
#    'up',
#    'and',
#    'took',
#    'a',
#    'bus',
#    'to',
#    'the',
#    'last',
#    'stop',
#    '.',
#    '<end>'],
#   ['<start>',
#    'And',
#    'we',
#    'went',
#    'to',
#    'our',
#    'uncle',
#    "'",
#    's',
#    'house',
#    'after',
#    'purchasing',
#    'it',
#    '.',
#    '<end>'],
#   ['<start>',
#    'After',
#    'we',
#    'arrived',
#    ',',
#    'we',
#    'ate',
#    'a',
#    'meal',
#    'and',
#    'played',
#    '.',
#    '<end>'],
#   ['<start>',
#    'We',
#    'went',
#    'to',
#    'a',
#    'famous',
#    'Korean',
#    'restaurant',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'was',
#    'going',
#    'to',
#    'go',
#    'to',
#    'Korea',
#    'at',
#    'that',
#    'time',
#    ',',
#    'but',
#    'I',
#    'could',
#    'not',
#    'go',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'went',
#    'for',
#    'a',
#    'school',
#    'consultation',
#    'for',
#    'my',
#    'sun',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'went',
#    'to',
#    'Seogwipo',
#    'today',
#    'after',
#    'school',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'went',
#    'to',
#    'a',
#    'ski',
#    'resort',
#    'with',
#    'my',
#    'friends',
#    'last',
#    'vacation',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'went',
#    'to',
#    'the',
#    'field',
#    'trip',
#    'with',
#    'my',
#    'classmates',
#    'this',
#    'time',
#    '.',
#    '<end>'],
#   ['<start>',
#    'This',
#    'winter',
#    'vacation',
#    'I',
#    'went',
#    'to',
#    'Everland',
#    'with',
#    'my',
#    'friends',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'came',
#    'home',
#    'with',
#    'my',
#    'dad',
#    'after',
#    'finishing',
#    'English',
#    'academy',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'went',
#    'to',
#    'home',
#    'plus',
#    'to',
#    'get',
#    'school',
#    'supplies',
#    '.',
#    '<end>'],
#   ['<start>',
#    'She',
#    'went',
#    'to',
#    'the',
#    'police',
#    'in',
#    'order',
#    'to',
#    'surrender',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'went',
#    'to',
#    'the',
#    'airport',
#    'to',
#    'pick',
#    'up',
#    'my',
#    'mom',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'went',
#    'to',
#    'the',
#    'station',
#    'to',
#    'accomplish',
#    'the',
#    'mission',
#    '.',
#    '<end>'],
#   ['<start>',
#    'We',
#    'went',
#    'to',
#    'the',
#    'shop',
#    'which',
#    'sells',
#    'Filipino',
#    'souvenir',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'went',
#    'to',
#    'the',
#    'beach',
#    'for',
#    'the',
#    'first',
#    'time',
#    'in',
#    'the',
#    'Philippines',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'ate',
#    'pizza',
#    'and',
#    'went',
#    'to',
#    'Ilsan',
#    'with',
#    'my',
#    'friends',
#    '.',
#    '<end>'],
#   ['<start>',
#    'So',
#    'we',
#    'went',
#    'to',
#    'Home',
#    'Plus',
#    'to',
#    'eat',
#    'dinner',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'had',
#    'good',
#    'rest',
#    'and',
#    'went',
#    'to',
#    'the',
#    'academy',
#    '.',
#    '<end>'],
#   ['<start>',
#    'She',
#    'left',
#    'the',
#    'phone',
#    'charger',
#    'at',
#    'my',
#    'place',
#    '.',
#    '<end>'],
#   ['<start>',
#    'Last',
#    'night',
#    ',',
#    'my',
#    'husband',
#    'was',
#    'rushed',
#    'to',
#    'the',
#    'emergency',
#    'room',
#    '.',
#    '<end>'],
#   ['<start>',
#    'My',
#    'colleague',
#    'in',
#    'my',
#    'team',
#    'took',
#    'a',
#    'holiday',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'went',
#    'to',
#    'see',
#    'an',
#    'orchestra',
#    'concert',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'went',
#    'to',
#    'a',
#    'supermarket',
#    'to',
#    'build',
#    'a',
#    'Christmas',
#    'tree',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'have',
#    'been',
#    'becoming',
#    'more',
#    'positive',
#    'through',
#    'this',
#    'class',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'went',
#    'to',
#    'church',
#    'last',
#    'Saturday',
#    'after',
#    'work',
#    '.',
#    '<end>'],
#   ['<start>',
#    'Badminton',
#    'club',
#    'members',
#    'and',
#    'I',
#    'went',
#    'to',
#    'a',
#    'picnic',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'woke',
#    'up',
#    'at',
#    'dawn',
#    'and',
#    'went',
#    'to',
#    'my',
#    'grandma',
#    "'",
#    's',
#    '.',
#    '<end>'],
#   ['<start>',
#    'Friends',
#    'went',
#    'early',
#    'because',
#    'of',
#    'the',
#    'boarding',
#    'time',
#    '.',
#    '<end>'],
#   ['<start>',
#    'We',
#    'watched',
#    'Eiffel',
#    'tower',
#    'and',
#    'then',
#    'went',
#    'to',
#    'Louvre',
#    'museum',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'took',
#    'the',
#    'Eurostar',
#    'to',
#    'get',
#    'to',
#    'the',
#    'France',
#    '.',
#    '<end>'],
#   ['<start>',
#    'She',
#    'went',
#    'to',
#    'hand',
#    'over',
#    'the',
#    'document',
#    'to',
#    'Mike',
#    '.',
#    '<end>'],
#   ['<start>',
#    'Children',
#    'went',
#    'to',
#    'grandmother',
#    "'",
#    's',
#    'home',
#    'to',
#    'give',
#    'cookies',
#    '.',
#    '<end>'],
#   ['<start>',
#    'He',
#    'went',
#    'to',
#    'school',
#    'to',
#    'learn',
#    'technologies',
#    'from',
#    'a',
#    'two',
#    'day',
#    'course',
#    '.',
#    '<end>'],
#   ['<start>',
#    'They',
#    'made',
#    'a',
#    'trip',
#    'to',
#    'KanKun',
#    'of',
#    'Mexico',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'went',
#    'to',
#    'the',
#    'supermarket',
#    'because',
#    'mom',
#    '.',
#    '<end>'],
#   ['<start>',
#    'Finally',
#    ',',
#    'I',
#    'went',
#    'to',
#    'the',
#    'bakery',
#    'to',
#    'make',
#    'the',
#    'cake',
#    '.',
#    '<end>'],
#   ['<start>',
#    'We',
#    'went',
#    'to',
#    'hyehwa',
#    'to',
#    'see',
#    'a',
#    'musical',
#    '.',
#    '<end>'],
#   ['<start>',
#    'A',
#    'couple',
#    'from',
#    'my',
#    'major',
#    'went',
#    'to',
#    'vacation',
#    'together',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'woke',
#    'up',
#    ',',
#    'had',
#    'a',
#    'breakfast',
#    'and',
#    'went',
#    'to',
#    'work',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'climbed',
#    'a',
#    'mountain',
#    'with',
#    'my',
#    'husband',
#    'after',
#    'breakfast',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'went',
#    'to',
#    'Myung',
#    'dong',
#    'with',
#    'my',
#    'girl',
#    'friend',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'went',
#    'to',
#    'my',
#    'friend',
#    "'",
#    's',
#    'father',
#    "'",
#    's',
#    'funeral',
#    'yesterday',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'went',
#    'to',
#    'my',
#    'son',
#    "'",
#    's',
#    'friends',
#    "'",
#    'birthday',
#    'party',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'went',
#    'to',
#    'eat',
#    'sushi',
#    'with',
#    'my',
#    'friend',
#    'yesterday',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'went',
#    'to',
#    'Art',
#    'Academy',
#    'with',
#    'my',
#    'best',
#    'friend',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'went',
#    'to',
#    'Daejeon',
#    'with',
#    'my',
#    'best',
#    'friend',
#    'Yerim',
#    '.',
#    '<end>'],
#   ['<start>',
#    'I',
#    'went',
#    'to',
# ...
#    '아',
#    '.',
#    '<end>'],
#   ['<start>',
#    '그',
#    '가',
#    '어제',
#    '제대로',
#    '말',
#    '을',
#    '못한',
#    '것',
#    '같',
#    '아',
#    '.',
#    '<end>'],
#   ['<start>',
#    '랩',
#    '으로',
#    '싼',
#    '제품',
#    '이',
#    '고정',
#    '이',
#    '안',
#    '된',
#    '것',
#    '같',
#    '아',
#    '.',
#    '<end>'],
#   ['<start>',
#    '어제',
#    '부터',
#    '숙제',
#    '를',
#    '미뤄',
#    '되게',
#    '피곤',
#    '한',
#    '하루',
#    '인',
#    '것',
#    '같',
#    '아',
#    '.',
#    '<end>'],
#   ['<start>',
#    '내',
#    '생각',
#    '엔',
#    '제자',
#    '가',
#    '시각',
#    '장애',
#    '인',
#    '이',
#    '아닌',
#    '것',
#    '같',
#    '아',
#    '.',
#    '<end>'],
#   ['<start>', '그래서', '수면제', '가', '필요', '했', '던', '것', '같', '아', '.', '<end>'],
#   ['<start>', '첫', '스텝', '이', '제일', '중요', '한', '것', '같', '아', '.', '<end>'],
#   ['<start>',
#    '고객',
#    '은',
#    '그',
#    '제품',
#    '을',
#    '사용',
#    '할',
#    '의지',
#    '를',
#    '여전히',
#    '가지',
#    '고',
#    '있',
#    '는',
#    '것',
#    '같',
#    '아',
#    '.',
#    '<end>'],
#   ['<start>',
#    '개인',
#    '적',
#    '으로',
#    '제어',
#    '가',
#    '더',
#    '재미있',
#    '는',
#    '것',
#    '같',
#    '아',
#    '.',
#    '<end>'],
#   ['<start>',
#    '감사',
#    '했',
#    '다고',
#    '제대로',
#    '말',
#    '하',
#    '지',
#    '않',
#    '으면',
#    '후회',
#    '할',
#    '것',
#    '같',
#    '아',
#    '.',
#    '<end>'],
#   ['<start>', '근데', '시간', '정말', '빨리', '가', '는', '것', '같', '아', '.', '<end>'],
#   ['<start>',
#    '그',
#    '가게',
#    '에',
#    '정말',
#    '오랜만',
#    '에',
#    '간',
#    '것',
#    '같',
#    '아',
#    '.',
#    '<end>'],
#   ['<start>',
#    '잉여금',
#    '을',
#    '조정',
#    '하',
#    '지',
#    '않',
#    '고',
#    '는',
#    '방법',
#    '이',
#    '없',
#    '는',
#    '거',
#    '같',
#    '아',
#    '.',
#    '<end>'],
#   ['<start>',
#    '눈',
#    '사람',
#    '을',
#    '정말',
#    '정성',
#    '스럽',
#    '게',
#    '만든',
#    '것',
#    '같',
#    '아',
#    '.',
#    '<end>'],
#   ['<start>',
#    '평소',
#    '에',
#    '도',
#    '걱정',
#    '이',
#    '많',
#    '은',
#    '성격',
#    '의',
#    '영향',
#    '이',
#    '큰',
#    '것',
#    '같',
#    '아',
#    '.',
#    '<end>'],
#   ['<start>',
#    '넌',
#    '여행',
#    '을',
#    '정말',
#    '좋',
#    '아',
#    '하',
#    '는',
#    '거',
#    '같',
#    '아',
#    '.',
#    '<end>'],
#   ['<start>',
#    '그',
#    '들',
#    '은',
#    '성',
#    '정체',
#    '성',
#    '이',
#    '다른',
#    '것',
#    '같',
#    '아',
#    '.',
#    '<end>'],
#   ['<start>', '디자이너', '는', '정말', '멋진', '직업', '인', '것', '같', '아', '.', '<end>'],
#   ['<start>',
#    '해리포터',
#    '는',
#    '정말',
#    '용맹',
#    '하',
#    '고',
#    '똑똑',
#    '한',
#    '것',
#    '같',
#    '아',
#    '.',
#    '<end>'],
#   ['<start>',
#    '체선',
#    '2',
#    '는',
#    '점점',
#    '더',
#    '예뻐',
#    '지',
#    '는',
#    '것',
#    '같',
#    '아',
#    '.',
#    '<end>'],
#   ['<start>',
#    '사람',
#    '들',
#    '이',
#    '점점',
#    '공유',
#    '를',
#    '하',
#    '면서',
#    '파일',
#    '다운로드',
#    '가',
#    '생긴',
#    '것',
#    '같',
#    '아',
#    '.',
#    '<end>'],
#   ['<start>',
#    '나',
#    '는',
#    '4',
#    '계절',
#    '스포츠',
#    '중',
#    '에',
#    '겨울',
#    '스포츠',
#    '가',
#    '제일',
#    '재미',
#    '있',
#    '는',
#    '거',
#    '같',
#    '아',
#    '.',
#    '<end>'],
#   ['<start>',
#    '아마',
#    '그',
#    '가',
#    '절',
#    '페이스',
#    '북',
#    '차단',
#    '한',
#    '것',
#    '같',
#    '아',
#    '.',
#    '<end>'],
#   ['<start>',
#    '아이',
#    '들',
#    '에',
#    '예절',
#    '은',
#    '부모',
#    '닝',
#    '의',
#    '거울',
#    '인',
#    '거',
#    '같',
#    '아',
#    '.',
#    '<end>'],
#   ['<start>',
#    '나',
#    '는',
#    '아까',
#    '전애',
#    '순수',
#    '한',
#    '너',
#    '에게',
#    '실수',
#    '를',
#    '한',
#    '것',
#    '같',
#    '아',
#    '.',
#    '<end>'],
#   ['<start>',
#    '군대',
#    '가',
#    '기',
#    '전이',
#    '술',
#    '을',
#    '많이',
#    '마시',
#    '는',
#    '것',
#    '같',
#    '아',
#    '.',
#    '<end>'],
#   ['<start>', '그', '가', '내', '충전기', '를', '가져간', '것', '같', '아', '.', '<end>'],
#   ['<start>',
#    '내',
#    '가',
#    '묻',
#    '기',
#    '전',
#    '에',
#    '말',
#    '해',
#    '줬',
#    '으면',
#    '좋',
#    '았',
#    '을',
#    '것',
#    '같',
#    '아',
#    '.',
#    '<end>'],
#   ['<start>',
#    '집',
#    '에서',
#    '는',
#    '얌전',
#    '하',
#    '고',
#    '부모',
#    '님',
#    '말씀',
#    '을',
#    '잘',
#    '듣',
#    '는',
#    '착한',
#    '어린이',
#    '일',
#    '것',
#    '같',
#    '아',
#    '.',
#    '<end>'],
#   ['<start>',
#    '토끼',
#    '는',
#    '활동',
#    '적',
#    '이',
#    '여서',
#    '나',
#    '랑',
#    '잘',
#    '맞',
#    '을',
#    '것',
#    '같',
#    '아',
#    '.',
#    '<end>'],
#   ['<start>',
#    '내',
#    '생각',
#    '엔',
#    '적극',
#    '적',
#    '이',
#    '고',
#    '밝',
#    '고',
#    '귀여운',
#    '여자',
#    '가',
#    '너',
#    '랑',
#    '어울릴',
#    '것',
#    '같',
#    '아',
#    '.',
#    '<end>'],
#   ['<start>',
#    '성격',
#    '은',
#    '개방',
#    '적',
#    '이',
#    '지만',
#    '약간',
#    '내성',
#    '적',
#    '인',
#    '것',
#    '같',
#    '아',
#    '.',
#    '<end>'],
#   ['<start>',
#    '만약',
#    '내',
#    '가',
#    '저',
#    '상황',
#    '이',
#    '라면',
#    '난',
#    '그러',
#    '지',
#    '못할',
#    '것',
#    '같',
#    '아',
#    '.',
#    '<end>'],
#   ['<start>',
#    '내',
#    '생각',
#    '에',
#    '쟤',
#    '네',
#    '사귀',
#    '는',
#    '거',
#    '같',
#    '아',
#    '.',
#    '<end>'],
#   ['<start>',
#    '네',
#    ',',
#    '나',
#    '를',
#    '재미없',
#    '다고',
#    '생각',
#    '할',
#    '것',
#    '같',
#    '아',
#    '.',
#    '<end>'],
#   ['<start>',
#    '내',
#    '가',
#    '쓴',
#    '문장',
#    '에',
#    '무엇',
#    '인가',
#    '오해',
#    '가',
#    '있',
#    '는',
#    '거',
#    '같',
#    '아',
#    '.',
#    '<end>'],
#   ['<start>',
#    '당분간',
#    '은',
#    '시장',
#    '의',
#    '움직임',
#    '을',
#    '지켜보',
#    '는',
#    '것',
#    '이',
#    '좋',
#    '을',
#    '것',
#    '같',
#    '아',
#    '.',
#    '<end>'],
#   ['<start>',
#    '올해',
#    '중',
#    '에',
#    '가장',
#    '많이',
#    '웃',
#    '은',
#    '거',
#    '같',
#    '아',
#    '.',
#    '<end>'],
#   ['<start>',
#    '내',
#    '가',
#    '오늘',
#    '잘',
#    '해서',
#    '복',
#    '을',
#    '받',
#    '은',
#    '것',
#    '같',
#    '아',
#    '.',
#    '<end>'],
#   ['<start>',
#    '늦',
#    '게',
#    '자',
#    '면',
#    '잘',
#    '수록',
#    '당신',
#    '이',
#    '보',
#    '고',
#    '싶',
#    '어',
#    '미칠',
#    '거',
#    '같',
#    '아',
#    '.',
#    '<end>'],
#   ['<start>',
#    '그',
#    '가',
#    '너',
#    '랑',
#    '잘',
#    '지냈',
#    '던',
#    '게',
#    '도움',
#    '이',
#    '된',
#    '것',
#    '같',
#    '아',
#    '.',
#    '<end>'],
#   ['<start>',
#    '너',
#    '기타',
#    '를',
#    '잘',
#    '치',
#    '면',
#    '매력',
#    '적',
#    '일',
#    '것',
#    '같',
#    '아',
#    '.',
#    '<end>'],
#   ['<start>',
#    '넌',
#    '내',
#    '말',
#    '을',
#    '잘못',
#    '알',
#    '아',
#    '들',
#    '은',
#    '것',
#    '같',
#    '아',
#    '.',
#    '<end>'],
#   ['<start>',
#    '띄어쓰기',
#    '만',
#    '잘',
#    '하',
#    '면',
#    '더',
#    '좋',
#    '을',
#    '것',
#    '같',
#    '아',
#    '.',
#    '<end>'],
#   ['<start>',
#    '내',
#    '인생',
#    '은',
#    '잘못',
#    '끼워',
#    '진',
#    '단추',
#    '와',
#    '같',
#    '아',
#    '.',
#    '<end>'],
#   ['<start>',
#    '나',
#    '는',
#    '문서',
#    '작성',
#    '을',
#    '잘',
#    '할',
#    '것',
#    '같',
#    '아',
#    '.',
#    '<end>'],
#   ['<start>',
#    '우리',
#    '의',
#    '수집',
#    '작품',
#    '중',
#    '에',
#    '추천',
#    '할',
#    '만',
#    '한',
#    '작품',
#    '도',
#    '있',
#    '을',
#    '것',
#    '같',
#    '아',
#    '.',
#    '<end>'],
#   ['<start>', '이제', '나', '혼자', '여행', '잘', '할', '것', '같', '아', '.', '<end>'],
#   ['<start>',
#    '우리',
#    '둘',
#    '만',
#    '자주',
#    '연락',
#    '하',
#    '는',
#    '것',
#    '같',
#    '아',
#    '.',
#    '<end>'],
#   ['<start>',
#    '영어',
#    '캠프',
#    '자료',
#    '준비',
#    '하',
#    '면',
#    '될',
#    '것',
#    '같',
#    '아',
#    '.',
#    '<end>'],
#   ['<start>',
#    '판도라',
#    '의',
#    '상자',
#    '를',
#    '열',
#    '어',
#    '버린',
#    '것',
#    '같',
#    '아',
#    '.',
#    '<end>'],
#   ['<start>',
#    '너',
#    '야말로',
#    '여자',
#    '친구',
#    '가',
#    '많',
#    '은',
#    '것',
#    '같',
#    '아',
#    '.',
#    '<end>'],
#   ['<start>',
#    '여동생',
#    '의',
#    '남자',
#    '친구',
#    '는',
#    '매우',
#    '좋',
#    '은',
#    '사람',
#    '같',
#    '아',
#    '.',
#    '<end>'],
#   ['<start>',
#    '그래서',
#    '시청자',
#    '들',
#    '이',
#    '한국',
#    '드라마',
#    '를',
#    '좋아하',
#    '는',
#    '것',
#    '같',
#    '아',
#    '.',
#    '<end>'],
#   ['<start>',
#    '귀여워서',
#    '남자',
#    '들',
#    '한테',
#    '인기',
#    '많',
#    '을',
#    '거',
#    '같',
#    '아',
#    '.',
#    '<end>'],
#   ['<start>',
#    '인생',
#    '은',
#    '나',
#    '자신',
#    '과',
#    '싸움',
#    '인',
#    '것',
#    '같',
#    '아',
#    '.',
#    '<end>'],
#   ['<start>',
#    '넌',
#    '정말',
#    '여자',
#    '마음',
#    '을',
#    '잘',
#    '아',
#    '는',
#    '거',
#    '같',
#    '아',
#    '.',
#    '<end>'],
#   ['<start>',
#    '화장품',
#    '은',
#    '여자',
#    '의',
#    '가장',
#    '소중',
#    '한',
#    '물건',
#    '인',
#    '것',
#    '같',
#    '아',
#    '.',
#    '<end>'],
#   ['<start>',
#    '나',
#    '는',
#    '혼자',
#    '있',
#    '을',
#    '때',
#    '대부분',
#    '인터넷',
#    '을',
#    '하',
#    '는',
#    '것',
#    '같',
#    '아',
#    '.',
#    '<end>'],
#   ['<start>',
#    '결국',
#    '남',
#    '아',
#    '있',
#    '는',
#    '사람',
#    '이',
#    '더',
#    '힘든',
#    '것',
#    '같',
#    '아',
#    '.',
#    '<end>'],
#   ['<start>',
#    '가장',
#    '오래',
#    '있',
#    '는',
#    '가족',
#    '은',
#    '아마',
#    '부모',
#    '님',
#    '인',
#    '것',
#    '같',
#    '아',
#    '.',
#    '<end>'],
#   ['<start>',
#    '내',
#    '가',
#    '입',
#    '고',
#    '있',
#    '는',
#    '모든',
#    '것',
#    '이',
#    '같',
#    '아',
#    '.',
#    '<end>'],
#   ['<start>',
#    '그',
#    '와',
#    '함께',
#    '있',
#    '으며',
#    '웃음',
#    '이',
#    '날',
#    '것',
#    '같',
#    '아',
#    '.',
#    '<end>'],
#   ['<start>',
#    '그',
#    '는',
#    '흥미',
#    '있',
#    '어',
#    '하',
#    '지',
#    '않',
#    '는',
#    '것',
#    '같',
#    '아',
#    '.',
#    '<end>'],
#   ['<start>',
#    '요즘',
#    '황사',
#    '있',
#    '어',
#    '산책',
#    '하',
#    '기',
#    '에',
#    '안',
#    '좋',
#    '은',
#    '것',
#    '같',
#    '아',
#    '.',
#    '<end>'],
#   ['<start>',
#    '눈',
#    '을',
#    '감',
#    '고',
#    '있',
#    '으면',
#    '그녀',
#    '가',
#    '보일',
#    '것',
#    '같',
#    '아',
#    '.',
#    '<end>'],
#   ['<start>',
#    '앞',
#    '으로',
#    '의미',
#    '있',
#    '는',
#    '일',
#    '이',
#    '더',
#    '많이',
#    '생길',
#    '것',
#    '같',
#    '아',
#    '.',
#    '<end>'],
#   ['<start>',
#    '공부',
#    '를',
#    '하',
#    '고',
#    '있',
#    '긴',
#    '한데',
#    '조금',
#    '부족',
#    '한',
#    '것',
#    '같',
#    '아',
#    '.',
#    '<end>'],
#   ['<start>', '하지만', '재미있', '는', '추억', '이', '된', '거', '같', '아', '.', '<end>'],
#   ['<start>',
#    '니',
#    '주변',
#    '에',
#    '있',
#    '는',
#    '여자',
#    '들',
#    '은',
#    '예쁠',
#    '것',
#    '같',
#    '아',
#    '.',
#    '<end>'],
#   ['<start>',
#    '다양',
#    '하',
#    '고',
#    '맛있',
#    '는',
#    '음식',
#    '덕분',
#    '에',
#    '후회',
#    '하',
#    '지',
#    '않',
#    '을',
#    '것',
#    '같',
#    '아',
#    '.',
#    '<end>'],
#   ['<start>',
#    '절대',
#    '네',
#    '생일',
#    '은',
#    '잊',
#    '지',
#    '못할',
#    '것',
#    '같',
#    '아',
#    '.',
#    '<end>'],
#   ['<start>',
#    '너',
#    '의',
#    '일',
#    '은',
#    '일정',
#    '이',
#    '빽빽',
#    '한',
#    '것',
#    '같',
#    '아',
#    '.',
#    '<end>'],
#   ['<start>',
#    '하',
#    '고',
#    '있',
#    '는',
#    '일',
#    '도',
#    '잘',
#    '될',
#    '것',
#    '같',
#    '아',
#    '.',
#    '<end>'],
#   ['<start>',
#    '내',
#    '가',
#    '지금',
#    '일',
#    '하',
#    '는',
#    '중',
#    '이',
#    '라서',
#    '확인',
#    '하',
#    '는',
#    '게',
#    '늦',
#    '을',
#    '것',
#    '같',
#    '아',
#    '.',
#    '<end>'],
#   ['<start>',
#    '오늘',
#    '따라',
#    '일',
#    '이',
#    '더',
#    '많',
#    '은',
#    '거',
#    '같',
#    '아',
#    '.',
#    '<end>'],
#   ['<start>',
#    '오늘',
#    '늦',
#    '게',
#    '일어나',
#    '서',
#    '모스',
#    '만',
#    '에',
#    '가',
#    '지',
#    '못할',
#    '거',
#    '같',
#    '아',
#    '.',
#    '<end>'],
#   ['<start>',
#    '하',
#    '고',
#    '싶',
#    '은',
#    '일',
#    '을',
#    '하',
#    '면',
#    '행복',
#    '할',
#    '것',
#    '같',
#    '아',
#    '.',
#    '<end>'],
#   ['<start>', '그', '금액', '을', '일치', '시켜야', '할', '것', '같', '아', '.', '<end>'],
#   ['<start>',
#    '그런데',
#    '토요일',
#    '에',
#    '너',
#    '는',
#    '항상',
#    '바쁜',
#    '것',
#    '같',
#    '아',
#    '.',
#    '<end>'],
#   ['<start>',
#    '아마도',
#    '수요일',
#    '쯤',
#    '보낼',
#    '수',
#    '있',
#    '을',
#    '거',
#    '같',
#    '아',
#    '.',
#    '<end>'],
#   ['<start>',
#    '아마도',
#    '일',
#    '주일',
#    '정도',
#    '지나',
#    '면',
#    '문제',
#    '가',
#    '없',
#    '을',
#    '것',
#    '같',
#    '아',
#    '.',
#    '<end>'],
#   ['<start>',
#    '아마도',
#    '토요일',
#    '밤',
#    '이나',
#    '일요일',
#    '아침',
#    '에',
#    '돌아오',
#    '게',
#    '될',
#    '것',
#    '같',
#    '아',
#    '.',
#    '<end>'],
#   ['<start>',
#    '난',
#    '모르',
#    '는',
#    '일',
#    '이',
#    '야',
#    '기온',
#    '때문',
#    '인',
#    '것',
#    '같',
#    '아',
#    '.',
#    '<end>'],
#   ['<start>',
#    '내',
#    '생각',
#    '에',
#    '일',
#    '할',
#    '때',
#    '에너지',
#    '가',
#    '넘칠',
#    '것',
#    '같',
#    '아',
#    '.',
#    '<end>'],
#   ['<start>', '그래서', '월요일', '에', '해야', '할', '거', '같', '아', '.', '<end>'],
#   ['<start>', '그', '식당', '은', '일종', '의', '공연장', '과', '같', '아', '.', '<end>'],
#   ['<start>',
#    '빨라야',
#    '토요일',
#    '에',
#    '보낼',
#    '수',
#    '있',
#    '을',
#    '것',
#    '같',
#    '아',
#    '.',
#    '<end>'],
#   ['<start>',
#    '당신',
#    '의',
#    '이메일',
#    '은',
#    '잘',
#    '못',
#    '전해진',
#    '것',
#    '같',
#    '아',
#    '.',
#    '<end>'],
#   ['<start>', '토요일', '일요일', '은', '더', '피곤', '한', '거', '같', '아', '.', '<end>'],
#   ['<start>',
#    '이번',
#    '주',
#    '목요일',
#    '이나',
#    '금요일',
#    '서울',
#    '에',
#    '갈',
#    '것',
#    '같',
#    '아',
#    '.',
#    '<end>'],
#   ['<start>',
#    '이번',
#    '주',
#    '금요일',
#    '날',
#    '에',
#    '못',
#    '만날',
#    '거',
#    '같',
#    '아',
#    '.',
#    '<end>'],
#   ['<start>',
#    '이번',
#    '주',
#    '까지',
#    '일',
#    '을',
#    '하',
#    '고',
#    '그만둬야',
#    '될',
#    '것',
#    '같',
#    '아',
#    '.',
#    '<end>'],
#   ['<start>',
#    '이번',
#    '주',
#    '토요일',
#    '에',
#    '파티',
#    '가',
#    '못',
#    '할',
#    '거',
#    '같',
#    '아',
#    '.',
#    '<end>'],
#   ['<start>', '미안', '한데', '내일', '못', '만', '날', '거', '같', '아', '.', '<end>'],
#   ['<start>',
#    '미안',
#    '한데',
#    '내일',
#    '사정',
#    '이',
#    '생겨',
#    '만나',
#    '지',
#    '못할',
#    '것',
#    '같',
#    '아',
#    '.',
#    '<end>'],
#   ['<start>', '그', '의', '무릎', '인대', '가', '다친', '것', '같', '아', '.', '<end>'],
#   ['<start>', '나', '는', '약간', '인터넷', '중독', '인', '것', '같', '아', '.', '<end>'],
#   ['<start>',
#    '누가',
#    '너',
#    '의',
#    '인',
#    '스타',
#    '그램',
#    '도용',
#    '하',
#    '는',
#    '것',
#    '같',
#    '아',
#    '.',
#    '<end>'],
#   ['<start>', '음악', '은', '내', '인생', '의', '오아시스', '와', '같', '아', '.', '<end>'],
#   ['<start>',
#    '그녀',
#    '의',
#    '곰',
#    '인형',
#    '은',
#    '공포',
#    '영화',
#    '에',
#    '나오',
#    '는',
#    '것',
#    '같',
#    '아',
#    '.',
#    '<end>'],
#   ['<start>',
#    '이것',
#    '이',
#    '미국인',
#    '들',
#    '을',
#    '힘들',
#    '게',
#    '하',
#    '는',
#    '것',
#    '같',
#    '아',
#    '.',
#    '<end>'],
#   ['<start>',
#    '이름',
#    '처럼',
#    '연인',
#    '들',
#    '이',
#    '오',
#    '면',
#    '좋',
#    '을',
#    '것',
#    '같',
#    '아',
#    '.',
#    '<end>'],
#   ['<start>',
#    '당신',
#    '응급실',
#    '이',
#    '라도',
#    '가',
#    '야',
#    '하',
#    '는',
#    '거',
#    '같',
#    '아',
#    '.',
#    '<end>'],
#   ['<start>',
#    '너',
#    '는',
#    '긍정',
#    '적',
#    '이',
#    '고',
#    '밝',
#    '은',
#    '사람',
#    '같',
#    '아',
#    '.',
#    '<end>'],
#   ['<start>',
#    '오늘',
#    '졸업식',
#    '이',
#    '있',
#    '어서',
#    '수업',
#    '에',
#    '빠져야',
#    '할',
#    '것',
#    '같',
#    '아',
#    '.',
#    '<end>'],
#   ['<start>',
#    '내',
#    '가',
#    '아픈',
#    '이유',
#    '는',
#    '너무',
#    '미국',
#    '음식',
#    '을',
#    '섭취',
#    '해',
#    '서',
#    '인',
#    '거',
#    '같',
#    '아',
#    '.',
#    '<end>'],
#   ['<start>',
#    '업무',
#    '스타일',
#    '이',
#    '나와',
#    '맞',
#    '지',
#    '않',
#    '는',
#    '것',
#    '같',
#    '아',
#    '.',
#    '<end>'],
#   ['<start>',
#    '니',
#    '가',
#    '좋',
#    '은',
#    '이유',
#    '가',
#    '단지',
#    '날',
#    '사랑',
#    '해',
#    '주',
#    '기',
#    '때문',
#    '인',
#    '거',
#    '같',
#    '아',
#    '.',
#    '<end>'],
#   ['<start>',
#    '집',
#    '에',
#    '가',
#    '면',
#    '이',
#    '영화',
#    '를',
#    '또',
#    '찾',
#    '을',
#    '것',
#    '같',
#    '아',
#    '.',
#    '<end>'],
#   ['<start>',
#    '역시',
#    '꿈',
#    '을',
#    '이루',
#    '는',
#    '데',
#    '에',
#    '는',
#    '경험',
#    '이',
#    '중요',
#    '한',
#    '것',
#    '같',
#    '아',
#    '.',
#    '<end>'],
#   ['<start>',
#    '앤디',
#    '지하철',
#    '이',
#    '조금',
#    '늦',
#    '게',
#    '도착',
#    '할',
#    '것',
#    '같',
#    '아',
#    '.',
#    '<end>'],
#   ['<start>',
#    '나',
#    '는',
#    '다음',
#    '달',
#    '이나',
#    '시간',
#    '이',
#    '될',
#    '것',
#    '같',
#    '아',
#    '.',
#    '<end>'],
#   ['<start>',
#    '그런',
#    '점',
#    '이',
#    '이',
#    '책',
#    '을',
#    '더',
#    '재밌',
#    '게',
#    '만들',
#    '어',
#    '주',
#    '는',
#    '것',
#    '같',
#    '아',
#    '.',
#    '<end>'],
#   ['<start>',
#    '너무',
#    '다혈질',
#    '이',
#    '라',
#    '참을성',
#    '이',
#    '부족',
#    '한',
#    '것',
#    '같',
#    '아',
#    '.',
#    '<end>'],
#   ['<start>',
#    '그',
#    '와',
#    '나',
#    '사이',
#    '에',
#    '는',
#    '마무리',
#    '될',
#    '것',
#    '같',
#    '아',
#    '.',
#    '<end>'],
#   ['<start>',
#    '어쩔',
#    '수',
#    '없이',
#    '널',
#    '계속',
#    '봐야',
#    '될',
#    '것',
#    '같',
#    '아',
#    '.',
#    '<end>'],
#   ['<start>',
#    '내',
#    '가',
#    '주인공',
#    '이',
#    '되',
#    '어서',
#    '사건',
#    '을',
#    '해결',
#    '해',
#    '나가',
#    '는',
#    '것',
#    '같',
#    '아',
#    '.',
#    '<end>'],
#   ['<start>',
#    '너',
#    '가',
#    '내',
#    '것',
#    '이',
#    '라면',
#    '너무나',
#    '행복',
#    '할',
#    '것',
#    '같',
#    '아',
#    '.',
#    '<end>'],
#   ['<start>',
#    '우리',
#    '가',
#    '학생',
#    '이',
#    '라서',
#    '통하',
#    '는',
#    '게',
#    '많',
#    '은',
#    '것',
#    '같',
#    '아',
#    '.',
#    '<end>'],
#   ['<start>',
#    '나',
#    '에게',
#    '권한',
#    '이',
#    '없',
#    '어서',
#    '안',
#    '열리',
#    '는',
#    '것',
#    '같',
#    '아',
#    '.',
#    '<end>'],
#   ['<start>', '그리고', '성격', '이', '나와', '비슷', '한', '것', '같', '아', '.', '<end>'],
#   ['<start>',
#    '그리고',
#    '할',
#    '말',
#    '이',
#    '있',
#    '다면',
#    '문자',
#    '로',
#    '하',
#    '는',
#    '게',
#    '좋',
#    '을',
#    '것',
#    '같',
#    '아',
#    '.',
#    '<end>'],
#   ...])

# %%
def tokenize(lang):
  lang_tokenizer = tf.keras.preprocessing.text.Tokenizer(
      filters='')
  lang_tokenizer.fit_on_texts(lang)

  tensor = lang_tokenizer.texts_to_sequences(lang)

  tensor = tf.keras.preprocessing.sequence.pad_sequences(tensor,
                                                         padding='post')

  return tensor, lang_tokenizer

# %%
inp_lang = preprocessing_src()
targ_lang = preprocessing_tar()

# %%
input_tensor, inp_lang = tokenize(inp_lang)
target_tensor, targ_lang = tokenize(targ_lang)

# %%
# src_sentence = df['ko'].tolist()
# tar_sentence = df['en'].tolist()

# src_sentence, tar_sentence

# %%
# word_pairs =[]
# for i, j in zip(src_sentence, tar_sentence):
#   word_pair = [i,j]
#   word_pairs.append(word_pair)

# word_pairs

# %%
# word_pairs[0]

# %%
input_tensor_train, input_tensor_val, target_tensor_train, target_tensor_val = train_test_split(input_tensor, target_tensor, test_size=0.2)

# %%
def convert(lang, tensor):
  for t in tensor:
    if t!=0:
      print ("%d ----> %s" % (t, lang.index_word[t]))

print ("Input Language; index to word mapping")
convert(inp_lang, input_tensor_train[0])
print ()
print ("Target Language; index to word mapping")
convert(targ_lang, target_tensor_train[0])
# Out:
# Input Language; index to word mapping
# 1 ----> <start>
# 16 ----> and
# 10 ----> is
# 34 ----> there
# 784 ----> additional
# 577 ----> fee
# 36 ----> if
# 4 ----> i
# 226 ----> ask
# 18 ----> for
# 784 ----> additional
# 6617 ----> beds
# 12 ----> ?
# 2 ----> <end>
#
# Target Language; index to word mapping
# 1 ----> <start>
# 92 ----> 그리고
# 4611 ----> 베드
# 13 ----> 를
# 341 ----> 추가
# 32 ----> 할
# 465 ----> 경우
# 341 ----> 추가
# 786 ----> 요금
# 4 ----> 이
# 10 ----> 있
# 107 ----> 습니까
# 17 ----> ?
# 2 ----> <end>

# %%
BUFFER_SIZE = len(input_tensor_train)
BATCH_SIZE = 64
steps_per_epoch = len(input_tensor_train)//BATCH_SIZE
embedding_dim = 256
units = 1024
vocab_inp_size = len(inp_lang.word_index)+1
vocab_tar_size = len(targ_lang.word_index)+1

dataset = tf.data.Dataset.from_tensor_slices((input_tensor_train, target_tensor_train)).shuffle(BUFFER_SIZE)
dataset = dataset.batch(BATCH_SIZE, drop_remainder=True)

# %%
example_input_batch, example_target_batch = next(iter(dataset))
example_input_batch.shape, example_target_batch.shape
# Out:
# (TensorShape([64, 24]), TensorShape([64, 32]))

# %%
class Encoder(tf.keras.Model):
  def __init__(self, vocab_size, embedding_dim, enc_units, batch_sz):
    super(Encoder, self).__init__()
    self.batch_sz = batch_sz
    self.enc_units = enc_units
    self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
    self.gru = tf.keras.layers.GRU(self.enc_units,
                                   return_sequences=True,
                                   return_state=True,
                                   recurrent_initializer='glorot_uniform')

  def call(self, x, hidden):
    x = self.embedding(x)
    output, state = self.gru(x, initial_state = hidden)
    return output, state

  def initialize_hidden_state(self):
    return tf.zeros((self.batch_sz, self.enc_units))

# %%
encoder = Encoder(vocab_inp_size, embedding_dim, units, BATCH_SIZE)

# sample input
sample_hidden = encoder.initialize_hidden_state()
sample_output, sample_hidden = encoder(example_input_batch, sample_hidden)
print ('Encoder output shape: (batch size, sequence length, units) {}'.format(sample_output.shape))
print ('Encoder Hidden state shape: (batch size, units) {}'.format(sample_hidden.shape))
# Out:
# Encoder output shape: (batch size, sequence length, units) (64, 24, 1024)
# Encoder Hidden state shape: (batch size, units) (64, 1024)

# %%
class BahdanauAttention(tf.keras.layers.Layer):
  def __init__(self, units):
    super(BahdanauAttention, self).__init__()
    self.W1 = tf.keras.layers.Dense(units)
    self.W2 = tf.keras.layers.Dense(units)
    self.V = tf.keras.layers.Dense(1)

  def call(self, query, values):
    # query hidden state shape == (batch_size, hidden size)
    # query_with_time_axis shape == (batch_size, 1, hidden size)
    # values shape == (batch_size, max_len, hidden size)
    # we are doing this to broadcast addition along the time axis to calculate the score
    query_with_time_axis = tf.expand_dims(query, 1)

    # score shape == (batch_size, max_length, 1)
    # we get 1 at the last axis because we are applying score to self.V
    # the shape of the tensor before applying self.V is (batch_size, max_length, units)
    score = self.V(tf.nn.tanh(
        self.W1(query_with_time_axis) + self.W2(values)))

    # attention_weights shape == (batch_size, max_length, 1)
    attention_weights = tf.nn.softmax(score, axis=1)

    # context_vector shape after sum == (batch_size, hidden_size)
    context_vector = attention_weights * values
    context_vector = tf.reduce_sum(context_vector, axis=1)

    return context_vector, attention_weights

# %%
attention_layer = BahdanauAttention(10)
attention_result, attention_weights = attention_layer(sample_hidden, sample_output)

print("Attention result shape: (batch size, units) {}".format(attention_result.shape))
print("Attention weights shape: (batch_size, sequence_length, 1) {}".format(attention_weights.shape))
# Out:
# Attention result shape: (batch size, units) (64, 1024)
# Attention weights shape: (batch_size, sequence_length, 1) (64, 24, 1)

# %%
class Decoder(tf.keras.Model):
  def __init__(self, vocab_size, embedding_dim, dec_units, batch_sz):
    super(Decoder, self).__init__()
    self.batch_sz = batch_sz
    self.dec_units = dec_units
    self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
    self.gru = tf.keras.layers.GRU(self.dec_units,
                                   return_sequences=True,
                                   return_state=True,
                                   recurrent_initializer='glorot_uniform')
    self.fc = tf.keras.layers.Dense(vocab_size)

    # used for attention
    self.attention = BahdanauAttention(self.dec_units)

  def call(self, x, hidden, enc_output):
    # enc_output shape == (batch_size, max_length, hidden_size)
    context_vector, attention_weights = self.attention(hidden, enc_output)

    # x shape after passing through embedding == (batch_size, 1, embedding_dim)
    x = self.embedding(x)

    # x shape after concatenation == (batch_size, 1, embedding_dim + hidden_size)
    x = tf.concat([tf.expand_dims(context_vector, 1), x], axis=-1)

    # passing the concatenated vector to the GRU
    output, state = self.gru(x)

    # output shape == (batch_size * 1, hidden_size)
    output = tf.reshape(output, (-1, output.shape[2]))

    # output shape == (batch_size, vocab)
    x = self.fc(output)

    return x, state, attention_weights

# %%
decoder = Decoder(vocab_tar_size, embedding_dim, units, BATCH_SIZE)

sample_decoder_output, _, _ = decoder(tf.random.uniform((BATCH_SIZE, 1)),
                                      sample_hidden, sample_output)

print ('Decoder output shape: (batch_size, vocab size) {}'.format(sample_decoder_output.shape))
# Out:
# Decoder output shape: (batch_size, vocab size) (64, 22026)

# %%
optimizer = tf.keras.optimizers.Adam()
loss_object = tf.keras.losses.SparseCategoricalCrossentropy(
    from_logits=True, reduction='none')

def loss_function(real, pred):
  mask = tf.math.logical_not(tf.math.equal(real, 0))
  loss_ = loss_object(real, pred)

  mask = tf.cast(mask, dtype=loss_.dtype)
  loss_ *= mask

  return tf.reduce_mean(loss_)

# %%
checkpoint_dir = '/content/drive/My Drive/seq2seq project/training_checkpoints'
checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt")
checkpoint = tf.train.Checkpoint(optimizer=optimizer,
                                 encoder=encoder,
                                 decoder=decoder)

# %%
@tf.function
def train_step(inp, targ, enc_hidden):
  loss = 0

  with tf.GradientTape() as tape:
    enc_output, enc_hidden = encoder(inp, enc_hidden)

    dec_hidden = enc_hidden

    dec_input = tf.expand_dims([targ_lang.word_index['<start>']] * BATCH_SIZE, 1)

    # Teacher forcing - feeding the target as the next input
    for t in range(1, targ.shape[1]):
      # passing enc_output to the decoder
      predictions, dec_hidden, _ = decoder(dec_input, dec_hidden, enc_output)

      loss += loss_function(targ[:, t], predictions)

      # using teacher forcing
      dec_input = tf.expand_dims(targ[:, t], 1)

  batch_loss = (loss / int(targ.shape[1]))

  variables = encoder.trainable_variables + decoder.trainable_variables

  gradients = tape.gradient(loss, variables)

  optimizer.apply_gradients(zip(gradients, variables))

  return batch_loss

# %%
EPOCHS = 10

for epoch in range(EPOCHS):
  start = time.time()

  enc_hidden = encoder.initialize_hidden_state()
  total_loss = 0

  for (batch, (inp, targ)) in enumerate(dataset.take(steps_per_epoch)):
    batch_loss = train_step(inp, targ, enc_hidden)
    total_loss += batch_loss

    if batch % 100 == 0:
      print('Epoch {} Batch {} Loss {:.4f}'.format(epoch + 1,
                                                   batch,
                                                   batch_loss.numpy()))
  # saving (checkpoint) the model every 2 epochs
  if (epoch + 1) % 2 == 0:
    checkpoint.save(file_prefix = checkpoint_prefix)

  print('Epoch {} Loss {:.4f}'.format(epoch + 1,
                                      total_loss / steps_per_epoch))
  print('Time taken for 1 epoch {} sec\n'.format(time.time() - start))
# Out:
# Epoch 1 Batch 0 Loss 4.3163
# Epoch 1 Batch 100 Loss 2.4722
# Epoch 1 Batch 200 Loss 2.1784
# Epoch 1 Batch 300 Loss 2.0631
# Epoch 1 Batch 400 Loss 2.0188
# Epoch 1 Batch 500 Loss 1.8777
# Epoch 1 Batch 600 Loss 1.8969
# Epoch 1 Batch 700 Loss 1.7368
# Epoch 1 Batch 800 Loss 1.7968
# Epoch 1 Batch 900 Loss 1.7056
# Epoch 1 Loss 2.0327
# Time taken for 1 epoch 892.0040111541748 sec
#
# Epoch 2 Batch 0 Loss 1.7127
# Epoch 2 Batch 100 Loss 1.6897
# Epoch 2 Batch 200 Loss 1.7126
# Epoch 2 Batch 300 Loss 1.7264
# Epoch 2 Batch 400 Loss 1.6460
# Epoch 2 Batch 500 Loss 1.5775
# Epoch 2 Batch 600 Loss 1.5510
# Epoch 2 Batch 700 Loss 1.6157
# Epoch 2 Batch 800 Loss 1.4586
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-29-bb8b18a677ee> in <module>()
#       7   total_loss = 0
#       8
# ----> 9   for (batch, (inp, targ)) in enumerate(dataset.take(steps_per_epoch)):
#      10     batch_loss = train_step(inp, targ, enc_hidden)
#      11     total_loss += batch_loss
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/data/ops/iterator_ops.py in __next__(self)
#     734
#     735   def __next__(self):  # For Python 3 compatibility
# --> 736     return self.next()
#     737
#     738   def _next_internal(self):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/data/ops/iterator_ops.py in next(self)
#     770   def next(self):
#     771     try:
# --> 772       return self._next_internal()
#     773     except errors.OutOfRangeError:
#     774       raise StopIteration
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/data/ops/iterator_ops.py in _next_internal(self)
#     748     # that there is no more data to iterate over.
#     749     # TODO(b/77291417): Fix
# --> 750     with context.execution_mode(context.SYNC):
#     751       with ops.device(self._device):
#     752         # TODO(ashankar): Consider removing this ops.device() context manager
#
# /usr/lib/python3.6/contextlib.py in __enter__(self)
#      79     def __enter__(self):
#      80         try:
# ---> 81             return next(self.gen)
#      82         except StopIteration:
#      83             raise RuntimeError("generator didn't yield") from None
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/context.py in execution_mode(mode)
#    2098     executor_old = ctx.executor
#    2099     try:
# -> 2100       executor_old.wait()
#    2101       ctx.executor = executor_new
#    2102       yield
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/executor.py in wait(self)
#      65   def wait(self):
#      66     """Waits for ops dispatched in this executor to finish."""
# ---> 67     pywrap_tfe.TFE_ExecutorWaitForAllPendingNodes(self._handle)
#      68
#      69   def clear_error(self):
#
# KeyboardInterrupt:

# %%
 def evaluate(sentence):
  attention_plot = np.zeros((max_length_targ, max_length_inp))

  sentence = preprocess_sentence(sentence)

  inputs = [inp_lang.word_index[i] for i in sentence.split(' ')]
  inputs = tf.keras.preprocessing.sequence.pad_sequences([inputs],
                                                         maxlen=max_length_inp,
                                                         padding='post')
  inputs = tf.convert_to_tensor(inputs)

  result = ''

  hidden = [tf.zeros((1, units))]
  enc_out, enc_hidden = encoder(inputs, hidden)

  dec_hidden = enc_hidden
  dec_input = tf.expand_dims([targ_lang.word_index['<start>']], 0)

  for t in range(max_length_targ):
    predictions, dec_hidden, attention_weights = decoder(dec_input,
                                                         dec_hidden,
                                                         enc_out)

    # storing the attention weights to plot later on
    attention_weights = tf.reshape(attention_weights, (-1, ))
    attention_plot[t] = attention_weights.numpy()

    predicted_id = tf.argmax(predictions[0]).numpy()

    result += targ_lang.index_word[predicted_id] + ' '

    if targ_lang.index_word[predicted_id] == '<end>':
      return result, sentence, attention_plot

    # the predicted ID is fed back into the model
    dec_input = tf.expand_dims([predicted_id], 0)

  return result, sentence, attention_plot

# %%
 # function for plotting the attention weights
def plot_attention(attention, sentence, predicted_sentence):
  fig = plt.figure(figsize=(10,10))
  ax = fig.add_subplot(1, 1, 1)
  ax.matshow(attention, cmap='viridis')

  fontdict = {'fontsize': 14}

  ax.set_xticklabels([''] + sentence, fontdict=fontdict, rotation=90)
  ax.set_yticklabels([''] + predicted_sentence, fontdict=fontdict)

  ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
  ax.yaxis.set_major_locator(ticker.MultipleLocator(1))

  plt.show()

# %%
def translate(sentence):
  result, sentence, attention_plot = evaluate(sentence)

  print('Input: %s' % (sentence))
  print('Predicted translation: {}'.format(result))

  attention_plot = attention_plot[:len(result.split(' ')), :len(sentence.split(' '))]
  plot_attention(attention_plot, sentence.split(' '), result.split(' '))

# %%
checkpoint.restore(tf.train.latest_checkpoint(checkpoint_dir))

# %%
translate(u'hace mucho frio aqui.')
